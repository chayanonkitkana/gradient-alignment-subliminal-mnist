# %%
import os
import math
import json
import time
import random
from dataclasses import dataclass, asdict
from pathlib import Path
from typing import Callable, Dict, List, Tuple, Optional

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, random_split

import torchvision
import torchvision.transforms as T

print("torch:", torch.__version__)
print("torchvision:", torchvision.__version__)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("device:", device)
# Out:
# torch: 2.10.0+cu128
# torchvision: 0.25.0+cu128
# device: cuda

# %%
# Liminal-style anchoring (KL-to-base) in auxiliary-logit distillation
#
# Conditions:
# - **Control**: normal auxiliary-logit distillation (student matches teacher aux logits on noise).
# - **Intervention (liminal anchor)**: augment distillation with a KL regularizer that anchors the student
#   to a frozen **base model** (the shared initialization) on selected logits:
#       L_total = L_distill_aux + lambda_k * KL(p_base^T || p_student^T)
#   where the anchor is computed either on:
#       - "reg10": the first 10 (MNIST) logits, or
#       - "all":   all (10 + aux) logits.
#   The weight lambda_k can be scheduled (strong early then decay) or kept constant throughout training.
#
# Measurements (logged every N steps):
# - trait loss (CE on first 10 logits, on audit batches)
# - distill loss (KL on aux logits, on current noise batch)
# - anchor loss (KL-to-base on selected logits, on current noise batch) and lambda_k
# - trait curvature along the *actual update direction* v (v^T H_trait v), where v is the gradient of L_total
# - alignment metrics computed at logging steps:
#     * pre:  alignment between g_distill (grad of L_distill_aux) and g_trait
#     * post: alignment between g_update  (grad of L_total)      and g_trait
# - final performance (student test accuracy on MNIST)
#
# Key detail:
# - The intervention does NOT require the trait gradient to form the update.
# - Therefore, audit batches are drawn only at logging steps (same as control).
#   At a logging step k, the same audit batches are used to compute:
#     (i) trait loss, (ii) trait curvature, and (iii) g_trait for alignment metrics.
#
# Output:
# - **one CSV per (seed, condition)**: runs/.../seed_01/control_metrics.csv, intervention_metrics.csv

# %%
@dataclass
class ExperimentConfig:
    # Runs
    seeds: List[int] = None # e.g., [1,2,...]
    out_dir: str = "./runs_mnist_liminal_anchor"

    # Data
    batch_size: int = 1024
    num_workers: int = 0  # keep 0 for strict determinism
    audit_size: int = 10_000
    noise_dataset_size: int = 60_000

    # Model (MLP from paper)
    hidden_dim: int = 256
    aux_m: int = 3

    # Training
    teacher_epochs: int = 5
    student_epochs: int = 5
    lr_teacher: float = 3e-4
    lr_student: float = 3e-4

    # Logging
    metrics_every_n_steps: int = 50
    # Number of audit batches used at logging steps to compute trait loss/curvature and g_trait.
    # For control, it's only used at logging steps.
    audit_batches_for_trait: int = 1

    # Numerics
    eps: float = 1e-12

    anchor_mode: str = "all"
    anchor_T: float = 2.0
    lambda0: float = 1.0

    anchor_schedule: str = "original"
    anchor_warmup_epochs: int = 1      # Unused if anchor_schedule = "original"
    anchor_decay_to_zero: bool = True  # Unused if anchor_schedule = "original"

cfg = ExperimentConfig(
    seeds=list(range(1, 101)),
    #seeds=[5],
    out_dir="/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised",
    batch_size=1024,
    num_workers=0,
    audit_size=10_000,
    noise_dataset_size=60_000,
    hidden_dim=256,
    aux_m=3,
    teacher_epochs=5,
    student_epochs=5,
    lr_teacher=3e-4,
    lr_student=3e-4,
    metrics_every_n_steps=1,
    audit_batches_for_trait=10,
    eps=1e-12,
    anchor_mode="aux",
    anchor_T=2.0,
    lambda0=1.0,
    anchor_schedule="original",
    anchor_warmup_epochs=1,              # Unused if anchor_schedule = "original"
    anchor_decay_to_zero=True,           # Unused if anchor_schedule = "original"
)

Path(cfg.out_dir).mkdir(parents=True, exist_ok=True)
cfg

def set_global_seed(seed: int, deterministic: bool = True) -> None:
    """Seed python, numpy, and torch. Optionally enable deterministic algorithms."""
    os.environ["PYTHONHASHSEED"] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

    if deterministic:
        torch.backends.cudnn.benchmark = False
        torch.backends.cudnn.deterministic = True
        try:
            torch.use_deterministic_algorithms(True)
        except Exception as e:
            print("Warning: could not enable full deterministic algorithms:", e)

def make_torch_generator(seed: int) -> torch.Generator:
    g = torch.Generator()
    g.manual_seed(seed)
    return g

class NoiseImages(Dataset):
    """Deterministic noise dataset: each index produces a reproducible noise image."""
    def __init__(self, length: int, seed: int, shape=(1, 28, 28), dist: str = "uniform"):
        self.length = int(length)
        self.seed = int(seed)
        self.shape = tuple(shape)
        self.dist = dist

    def __len__(self) -> int:
        return self.length

    def __getitem__(self, idx: int):
        # Per-index deterministic generation.
        g = torch.Generator()
        g.manual_seed(self.seed * 1_000_000 + int(idx))
        if self.dist == "normal":
            x = torch.randn(self.shape, generator=g)
        elif self.dist == "uniform":
            x = torch.rand(self.shape, generator=g) * 2 - 1
        else:
            raise ValueError(f"Unknown dist: {self.dist}")
        # Dummy label (unused)
        y = 0
        return x, y

def get_mnist_datasets(root: str):
    transform = T.Compose([T.ToTensor(), T.Normalize((0.5), (0.5))])
    train = torchvision.datasets.MNIST(root=root, train=True, download=True, transform=transform)
    test = torchvision.datasets.MNIST(root=root, train=False, download=True, transform=transform)
    return train, test

def split_train_audit(train_ds, audit_size: int, seed: int):
    n = len(train_ds)
    audit_size = min(int(audit_size), n)
    train_size = n - audit_size
    g = make_torch_generator(seed)
    train_split, audit_split = random_split(train_ds, [train_size, audit_size], generator=g)
    return train_split, audit_split

def make_loader(ds, batch_size: int, shuffle: bool, seed: int, num_workers: int = 0):
    # Deterministic shuffling via DataLoader generator.
    g = make_torch_generator(seed)
    return DataLoader(
        ds,
        batch_size=batch_size,
        shuffle=shuffle,
        num_workers=num_workers,
        pin_memory=torch.cuda.is_available(),
        generator=g,
        drop_last=False,
    )

class MLPClassifier(nn.Module):
    """MLP from the Subliminal Learning MNIST experiment: (784, 256, 256, 10+m) with ReLU."""
    def __init__(self, hidden_dim: int = 256, aux_m: int = 3):
        super().__init__()
        self.hidden_dim = hidden_dim
        self.aux_m = aux_m
        self.fc1 = nn.Linear(28 * 28, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, 10 + aux_m)

        for layer in [self.fc1, self.fc2, self.fc3]:
            nn.init.normal_(layer.weight, 0.0, 1 / math.sqrt(layer.in_features))
            nn.init.zeros_(layer.bias)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

def build_model_mlp(cfg: ExperimentConfig) -> nn.Module:
    """Swap model architecture by changing this builder (or passing another builder to the runner)."""
    return MLPClassifier(hidden_dim=cfg.hidden_dim, aux_m=cfg.aux_m)

def logits_regular(logits: torch.Tensor) -> torch.Tensor:
    return logits[:, :10]

def logits_aux(logits: torch.Tensor, aux_m: int) -> torch.Tensor:
    return logits[:, 10:10 + aux_m]

@torch.no_grad()
def accuracy_on_loader(model: nn.Module, loader: DataLoader, device: torch.device) -> float:
    model.eval()
    correct, total = 0, 0
    for x, y in loader:
        x, y = x.to(device), y.to(device)
        pred = logits_regular(model(x)).argmax(dim=1)
        correct += (pred == y).sum().item()
        total += y.numel()
    return correct / max(total, 1)

def get_params(model: nn.Module) -> List[torch.nn.Parameter]:
    return [p for p in model.parameters() if p.requires_grad]

def flatten_grads_from_params(params: List[torch.nn.Parameter]) -> torch.Tensor:
    """Flatten gradients already stored in .grad (e.g., after backward())."""
    flats = []
    for p in params:
        if p.grad is None:
            flats.append(torch.zeros_like(p).view(-1))
        else:
            flats.append(p.grad.detach().view(-1))
    return torch.cat(flats)

def split_flat_like_params(params: List[torch.nn.Parameter], flat: torch.Tensor) -> List[torch.Tensor]:
    out = []
    offset = 0
    for p in params:
        n = p.numel()
        out.append(flat[offset:offset + n].view_as(p))
        offset += n
    assert offset == flat.numel()
    return out

def train_teacher(
    model: nn.Module,
    train_loader: DataLoader,
    test_loader: DataLoader,
    cfg: ExperimentConfig,
    device: torch.device,
) -> Dict[str, float]:
    """Train teacher on MNIST CE using regular logits only."""
    model = model.to(device)
    model.train()
    opt = torch.optim.Adam(model.parameters(), lr=cfg.lr_teacher)

    for _epoch in range(cfg.teacher_epochs):
        for x, y in train_loader:
            x, y = x.to(device), y.to(device)
            opt.zero_grad(set_to_none=True)
            loss = F.cross_entropy(logits_regular(model(x)), y)
            loss.backward()
            opt.step()

    teacher_acc = accuracy_on_loader(model, test_loader, device)
    return {"teacher_test_acc": float(teacher_acc)}

def make_infinite_iterator(loader: DataLoader):
    it = iter(loader)
    while True:
        try:
            yield next(it)
        except StopIteration:
            it = iter(loader)

@torch.no_grad()
def collect_audit_batches(audit_stream, num_batches: int) -> List[Tuple[torch.Tensor, torch.Tensor]]:
    return [next(audit_stream) for _ in range(num_batches)]

def trait_loss_on_batches(
    model: nn.Module,
    batches: List[Tuple[torch.Tensor, torch.Tensor]],
    device: torch.device,
) -> torch.Tensor:
    losses = []
    for x, y in batches:
        x, y = x.to(device), y.to(device)
        losses.append(F.cross_entropy(logits_regular(model(x)), y))
    return torch.stack(losses).mean()

def compute_trait_grad_flat_from_batches(
    model: nn.Module,
    params: List[torch.nn.Parameter],
    batches: List[Tuple[torch.Tensor, torch.Tensor]],
    device: torch.device,
) -> Tuple[float, torch.Tensor]:
    loss = trait_loss_on_batches(model, batches, device)
    grads = torch.autograd.grad(loss, params, retain_graph=False, create_graph=False)
    g_flat = torch.cat([g.detach().view(-1) for g in grads])
    return float(loss.detach()), g_flat

def compute_trait_loss_and_curvature_vHv_from_batches(
    model: nn.Module,
    params: List[torch.nn.Parameter],
    batches: List[Tuple[torch.Tensor, torch.Tensor]],
    v_flat: torch.Tensor,
    device: torch.device,
) -> Tuple[float, float, float]:
    """
    Returns:
      trait_loss, v^T H v, (v^T H v) / ||v||^2
    """
    loss = trait_loss_on_batches(model, batches, device)

    grads = torch.autograd.grad(loss, params, retain_graph=True, create_graph=True)

    v_list = split_flat_like_params(params, v_flat.detach())
    gv = torch.zeros((), device=device)
    for g, v in zip(grads, v_list):
        gv = gv + (g * v).sum()

    hvp = torch.autograd.grad(gv, params, retain_graph=False, create_graph=False)
    hvp_flat = torch.cat([h.detach().view(-1) for h in hvp])

    v_det = v_flat.detach()
    vHv = float((v_det @ hvp_flat).detach())
    v_norm2 = float((v_det @ v_det).detach())
    vHv_norm = vHv / max(v_norm2, 1e-30)

    return float(loss.detach()), vHv, vHv_norm

def distill_loss_aux_only(student: nn.Module, teacher: nn.Module, x_noise: torch.Tensor, aux_m: int) -> torch.Tensor:
    with torch.no_grad():
        t_aux = logits_aux(teacher(x_noise), aux_m)
        t_prob = F.softmax(t_aux, dim=1)

    s_aux = logits_aux(student(x_noise), aux_m)
    s_logprob = F.log_softmax(s_aux, dim=1)

    kl = torch.nn.KLDivLoss(reduction="batchmean")
    return kl(s_logprob, t_prob)

# Intervention: liminal-training-style regularization
def select_logits_for_anchor(logits: torch.Tensor, mode: str, aux_m: int) -> torch.Tensor:
    if mode == "reg10":
        return logits[:, :10]
    if mode == "aux":
        return logits[:, 10:10 + aux_m]
    if mode == "all":
        return logits
    raise ValueError(f"Unknown anchor_mode={mode}")

def kl_anchor_to_base(
    student: nn.Module,
    base: nn.Module,
    x: torch.Tensor,
    cfg: ExperimentConfig,
) -> torch.Tensor:
    """
    KL(p_base^T || p_student^T) computed on selected logits (reg10 or all).
    Uses KLDivLoss(log p_student, p_base) which equals KL(p_base || p_student).
    """
    kl = torch.nn.KLDivLoss(reduction="batchmean")
    T = cfg.anchor_T

    with torch.no_grad():
        b = select_logits_for_anchor(base(x), cfg.anchor_mode, cfg.aux_m) / T
        p_base = F.softmax(b, dim=1)

    s = select_logits_for_anchor(student(x), cfg.anchor_mode, cfg.aux_m) / T
    logp_student = F.log_softmax(s, dim=1)

    return (T ** 2) * kl(logp_student, p_base)

def anchor_lambda(epoch: int, global_step: int, steps_per_epoch: int, cfg: ExperimentConfig) -> float:
    """
    Schedule for lambda_k:
      - constant: lambda0 throughout
      - early_then_decay: lambda0 for first `anchor_warmup_epochs` epochs,
        then (optionally) linear decay to 0 by end of training
    """
    if cfg.lambda0 <= 0:
        return 0.0

    if cfg.anchor_schedule == "constant":
        return float(cfg.lambda0)

    if cfg.anchor_schedule == "early_then_decay":
        # Warmup phase
        if epoch < cfg.anchor_warmup_epochs:
            return float(cfg.lambda0)

        # After warmup
        if not cfg.anchor_decay_to_zero:
            return float(cfg.lambda0)

        total_steps = steps_per_epoch * cfg.student_epochs
        warmup_steps = steps_per_epoch * cfg.anchor_warmup_epochs
        remaining = max(total_steps - warmup_steps, 1)

        t = (global_step - warmup_steps) / remaining  # This does not perfectly become 0 at the end
        return float(cfg.lambda0 * max(0.0, 1.0 - t))

    if cfg.anchor_schedule == "original":
        return float(anchor_lambda_original(global_step, steps_per_epoch, cfg))

    raise ValueError(f"Unknown anchor_schedule={cfg.anchor_schedule}")

def anchor_lambda_original(global_step: int, steps_per_epoch: int, cfg: ExperimentConfig) -> float:
    """
    Implements Yanagisawa et al. (Liminal Training) Eq. (3)-(4):
      - Phase 1 (first epoch): anneal from lambda0 to 1 (except lambda0 = 1 case)
      - Phase 2 (rest): decay linearly to 0 with scale lambda0
    """
    lambda0 = float(cfg.lambda0)
    if lambda0 <= 0:
        return 0.0

    total_steps = steps_per_epoch * cfg.student_epochs
    if total_steps <= 1:
        return lambda0

    # normalized training progress t in [0,1]
    t = global_step / (total_steps - 1)

    E = float(cfg.student_epochs)
    tau2 = 1.0 / E  # end of first epoch in normalized time

    if t <= tau2 + 1e-12:
        # Phase 1: lambda(t) = 1 + (lambda0 - 1) * (1 - t/tau2)
        s = t / max(tau2, 1e-12)
        return 1.0 + (lambda0 - 1.0) * (1.0 - s)
    else:
        # Phase 2: lambda(t) = lambda0 * (1 - (t - tau2)/(1 - tau2))
        s = (t - tau2) / max(1.0 - tau2, 1e-12)
        return lambda0 * max(0.0, 1.0 - s)

# Student run (control vs intervention)
# Key detail (liminal anchoring):
# - In **intervention**, the update is computed from
#       L_total = L_distill_aux + lambda_k * KL_anchor(student || base)
#   so it does NOT require the trait gradient.
# - Therefore, audit batches are drawn only at logging steps (same as control),
#   and are used solely to compute:
#       (i) trait loss / curvature, and
#       (ii) alignment metrics between g_trait and the actual update gradient g_update.
# - At a logging step k, the same audit batches are used for trait loss, curvature,
#   and g_trait (for alignment), ensuring consistency of logged quantities.
def run_student_condition(
    condition: str,  # "control" or "intervention"
    student: nn.Module,
    teacher: nn.Module,
    base_model: nn.Module,
    noise_loader: DataLoader,
    audit_loader: DataLoader,
    test_loader: DataLoader,
    cfg: ExperimentConfig,
    seed: int,
    device: torch.device,
) -> Tuple[pd.DataFrame, Dict[str, float]]:
    assert condition in ("control", "intervention")
    assert cfg.audit_batches_for_trait >= 1

    student = student.to(device)
    teacher = teacher.to(device)
    teacher.eval()
    for p in teacher.parameters():
        p.requires_grad_(False)

    params = get_params(student)
    opt = torch.optim.Adam(student.parameters(), lr=cfg.lr_student)

    audit_stream = make_infinite_iterator(audit_loader)

    logs: List[Dict[str, float]] = []
    global_step = 0
    steps_per_epoch = len(noise_loader)

    student.train()
    for epoch in range(cfg.student_epochs):
        for x_noise, _ in noise_loader:
            x_noise = x_noise.to(device)
#
            # Decide if we log this step (needed before computing g_distill)
            do_log = (global_step % cfg.metrics_every_n_steps == 0)

            # --- Forward losses ---
            opt.zero_grad(set_to_none=True)

            dloss = distill_loss_aux_only(student, teacher, x_noise, cfg.aux_m)

            lam = 0.0
            anchor_loss = torch.tensor(0.0, device=device)

            if condition == "intervention":
                lam = anchor_lambda(epoch, global_step, steps_per_epoch, cfg)
                if lam > 0.0:
                    anchor_loss = kl_anchor_to_base(student, base_model, x_noise, cfg)

            # If logging, compute distill-only gradient (pre) without touching .grad
            g_distill = None
            if do_log:
                grads_distill = torch.autograd.grad(dloss, params, retain_graph=True, create_graph=False)
                g_distill = torch.cat([g.detach().view(-1) for g in grads_distill])

            # --- Backward actual update gradient ---
            total_loss = dloss + lam * anchor_loss
            total_loss.backward()

            # Actual update direction (post)
            g_update = flatten_grads_from_params(params)
#
            # --- logging: trait loss + curvature + alignment (pre vs post) ---
            if do_log:
                # Draw trait batches only at logging steps (both conditions)
                trait_batches_k = collect_audit_batches(audit_stream, cfg.audit_batches_for_trait)
                # Trait grad on these batches
                _trait_loss_tmp, g_trait = compute_trait_grad_flat_from_batches(
                    model=student,
                    params=params,
                    batches=trait_batches_k,
                    device=device,
                )

                # Trait loss + curvature along actual update direction g_update
                trait_loss_val, vHv, vHv_norm = compute_trait_loss_and_curvature_vHv_from_batches(
                    model=student,
                    params=params,
                    batches=trait_batches_k,
                    v_flat=g_update,
                    device=device,
                )

                # Alignment metrics: pre (distill-only) vs post (actual update)
                inner_pre = float((g_distill @ g_trait).detach()) if g_distill is not None else np.nan
                cos_pre = float((g_distill @ g_trait).detach() / ((g_distill.norm() * g_trait.norm()).clamp_min(cfg.eps))) if g_distill is not None else np.nan

                inner_post = float((g_update @ g_trait).detach())
                cos_post = float((g_update @ g_trait).detach() / ((g_update.norm() * g_trait.norm()).clamp_min(cfg.eps)))

                logs.append({
                    "seed": seed,
                    "condition": condition,
                    "step": global_step,
                    "epoch": epoch,

                    "trait_loss": trait_loss_val,
                    "distill_loss": float(dloss.detach()),
                    "total_loss": float(total_loss.detach()),

                    "trait_curvature_vHv": vHv,
                    "trait_curvature_vHv_norm": vHv_norm,

                    "inner_pre": inner_pre,
                    "cos_pre": cos_pre,
                    "inner_post": inner_post,
                    "cos_post": cos_post,

                    "lambda_k": float(lam),
                    "anchor_loss": float(anchor_loss.detach()),
                    "anchor_mode": cfg.anchor_mode,
                    "anchor_schedule": cfg.anchor_schedule,
                })

            opt.step()
            global_step += 1

    student_acc = accuracy_on_loader(student, test_loader, device)

    df = pd.DataFrame(logs)
    info = {
        "student_test_acc": float(student_acc),
        "total_steps": int(global_step),
        "num_logged_rows": int(len(df)),
    }

    return df, info

# Aggregate summary across runs
def aggregate_across_runs(out_dir: str, epoch=None) -> pd.DataFrame:
    out_dir = Path(out_dir)
    rows = []
    for seed_dir in sorted(out_dir.glob("seed_*")):
        for cond, fname in [("control", "control_metrics.csv"), ("intervention", "intervention_metrics.csv")]:
            p = seed_dir / fname
            if not p.exists():
                continue

            df = pd.read_csv(p)
            if len(df) == 0:
                continue

            if epoch is not None:
                if isinstance(epoch, (list, tuple, set, np.ndarray, pd.Series)):
                    df = df[df["epoch"].isin(list(epoch))]
                else:
                    df = df[df["epoch"] == int(epoch)]
                if len(df) == 0:
                    continue

            # Helpers for safe means
            def _mean(col: str):
                return float(df[col].mean()) if col in df.columns else np.nan

            rows.append({
                "seed": int(df["seed"].iloc[0]),
                "condition": cond,

                # performance
                "teacher_test_acc": float(df["teacher_test_acc"].iloc[0]) if "teacher_test_acc" in df.columns else np.nan,
                "student_test_acc": float(df["student_test_acc"].iloc[0]) if "student_test_acc" in df.columns else np.nan,

                # losses
                "mean_trait_loss": _mean("trait_loss"),
                "mean_distill_loss": _mean("distill_loss"),

                # curvature
                "mean_trait_curvature_vHv": _mean("trait_curvature_vHv"),
                "mean_trait_curvature_vHv_norm": _mean("trait_curvature_vHv_norm"),

                # alignment summaries
                "mean_inner_pre": _mean("inner_pre"),
                "mean_cos_pre": _mean("cos_pre"),
                "mean_inner_post": _mean("inner_post"),
                "mean_cos_post": _mean("cos_post"),

                # fractions of positive alignment (pre/post)
                "frac_pos_pre": float((df["inner_pre"] > 0).mean()) if "inner_pre" in df.columns else np.nan,
                "frac_pos_post": float((df["inner_post"] > 0).mean()) if "inner_post" in df.columns else np.nan,

                "num_logged_rows": int(len(df)),
            })

    return pd.DataFrame(rows).sort_values(["seed", "condition"]).reset_index(drop=True)

# One seed: train teacher once, run control + intervention students
def run_one_seed(
    seed: int,
    cfg: ExperimentConfig,
    build_model_fn: Callable[[ExperimentConfig], nn.Module],
    device: torch.device,
) -> Dict[str, Path]:
    set_global_seed(seed, deterministic=True)

    run_dir = Path(cfg.out_dir) / f"seed_{seed:02d}"
    run_dir.mkdir(parents=True, exist_ok=True)

    # Data
    data_root = str(Path(cfg.out_dir) / "data_cache")
    mnist_train, mnist_test = get_mnist_datasets(root=data_root)
    train_split, audit_split = split_train_audit(mnist_train, audit_size=cfg.audit_size, seed=seed)

    train_loader = make_loader(train_split, cfg.batch_size, shuffle=True,  seed=seed + 100, num_workers=cfg.num_workers)
    audit_loader = make_loader(audit_split, cfg.batch_size, shuffle=True,  seed=seed + 200, num_workers=cfg.num_workers)
    test_loader  = make_loader(mnist_test,  cfg.batch_size, shuffle=False, seed=seed + 300, num_workers=cfg.num_workers)

    # Same noise ordering for both conditions
    noise_ds = NoiseImages(length=cfg.noise_dataset_size, seed=seed + 400, shape=(1, 28, 28), dist="uniform")
    noise_loader_control = make_loader(noise_ds, cfg.batch_size, shuffle=True, seed=seed + 500, num_workers=cfg.num_workers)
    noise_loader_interv  = make_loader(noise_ds, cfg.batch_size, shuffle=True, seed=seed + 500, num_workers=cfg.num_workers)

    # Reference init
    reference = build_model_fn(cfg)
    ref_state = {k: v.clone().detach().cpu() for k, v in reference.state_dict().items()}
    # Base model for anchoring (same init as teacher/student), frozen
    base_model = build_model_fn(cfg)
    base_model.load_state_dict(ref_state)
    base_model = base_model.to(device)
    base_model.eval()
    for p in base_model.parameters():
        p.requires_grad_(False)

    # Teacher
    teacher = build_model_fn(cfg)
    teacher.load_state_dict(ref_state)
    teacher_info = train_teacher(teacher, train_loader, test_loader, cfg, device)

    # Students (same init)
    student_control = build_model_fn(cfg); student_control.load_state_dict(ref_state)
    student_interv  = build_model_fn(cfg); student_interv.load_state_dict(ref_state)

    # Run conditions
    control_df, control_info = run_student_condition(
        condition="control",
        student=student_control,
        teacher=teacher,
        base_model=base_model,
        noise_loader=noise_loader_control,
        audit_loader=audit_loader,
        test_loader=test_loader,
        cfg=cfg,
        seed=seed,
        device=device,
    )
    interv_df, interv_info = run_student_condition(
        condition="intervention",
        student=student_interv,
        teacher=teacher,
        base_model=base_model,
        noise_loader=noise_loader_interv,
        audit_loader=audit_loader,
        test_loader=test_loader,
        cfg=cfg,
        seed=seed,
        device=device,
    )

    # Add final perf to all rows
    for df, info in [(control_df, control_info), (interv_df, interv_info)]:
        df["teacher_test_acc"] = teacher_info["teacher_test_acc"]
        df["student_test_acc"] = info["student_test_acc"]
        df["total_steps"] = info["total_steps"]

    # Save
    control_csv = run_dir / "control_metrics.csv"
    interv_csv  = run_dir / "intervention_metrics.csv"
    control_df.to_csv(control_csv, index=False)
    interv_df.to_csv(interv_csv, index=False)

    meta = {
        "seed": seed,
        "config": asdict(cfg),
        "teacher_info": teacher_info,
        "control_info": control_info,
        "intervention_info": interv_info,
        "created_at_utc": time.strftime("%Y-%m-%dT%H:%M:%SZ", time.gmtime()),
        "device": str(device),
    }
    with open(run_dir / "metadata.json", "w") as f:
        json.dump(meta, f, indent=2)

    print(
        f"[seed {seed}] teacher_acc={teacher_info['teacher_test_acc']:.4f} | "
        f"control_acc={control_info['student_test_acc']:.4f} | "
        f"interv_acc={interv_info['student_test_acc']:.4f} | "
        f"rows(control/interv)={len(control_df)}/{len(interv_df)}"
    )

    return {"control_csv": control_csv, "intervention_csv": interv_csv}

# Run all seeds (1..10)
all_paths = []
for s in cfg.seeds:
    all_paths.append(run_one_seed(seed=s, cfg=cfg, build_model_fn=build_model_mlp, device=device))

all_paths[0]
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 18.8MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 481kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.78MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 29.4MB/s]
# [seed 1] teacher_acc=0.9351 | control_acc=0.6093 | interv_acc=0.5136 | rows(control/interv)=295/295
# [seed 2] teacher_acc=0.9364 | control_acc=0.4254 | interv_acc=0.3254 | rows(control/interv)=295/295
# [seed 3] teacher_acc=0.9402 | control_acc=0.5991 | interv_acc=0.5471 | rows(control/interv)=295/295
# [seed 4] teacher_acc=0.9375 | control_acc=0.7604 | interv_acc=0.6817 | rows(control/interv)=295/295
# [seed 5] teacher_acc=0.9387 | control_acc=0.5844 | interv_acc=0.5585 | rows(control/interv)=295/295
# [seed 6] teacher_acc=0.9354 | control_acc=0.6748 | interv_acc=0.6218 | rows(control/interv)=295/295
# [seed 7] teacher_acc=0.9369 | control_acc=0.4449 | interv_acc=0.3733 | rows(control/interv)=295/295
# [seed 8] teacher_acc=0.9388 | control_acc=0.6094 | interv_acc=0.5517 | rows(control/interv)=295/295
# [seed 9] teacher_acc=0.9354 | control_acc=0.5950 | interv_acc=0.4820 | rows(control/interv)=295/295
# [seed 10] teacher_acc=0.9401 | control_acc=0.3386 | interv_acc=0.2715 | rows(control/interv)=295/295
# [seed 11] teacher_acc=0.9376 | control_acc=0.6422 | interv_acc=0.5342 | rows(control/interv)=295/295
# [seed 12] teacher_acc=0.9407 | control_acc=0.3960 | interv_acc=0.3457 | rows(control/interv)=295/295
# [seed 13] teacher_acc=0.9325 | control_acc=0.5034 | interv_acc=0.4511 | rows(control/interv)=295/295
# [seed 14] teacher_acc=0.9398 | control_acc=0.6499 | interv_acc=0.5707 | rows(control/interv)=295/295
# [seed 15] teacher_acc=0.9388 | control_acc=0.4859 | interv_acc=0.4053 | rows(control/interv)=295/295
# [seed 16] teacher_acc=0.9366 | control_acc=0.5816 | interv_acc=0.5081 | rows(control/interv)=295/295
# [seed 17] teacher_acc=0.9412 | control_acc=0.5530 | interv_acc=0.4934 | rows(control/interv)=295/295
# [seed 18] teacher_acc=0.9385 | control_acc=0.6161 | interv_acc=0.5569 | rows(control/interv)=295/295
# [seed 19] teacher_acc=0.9363 | control_acc=0.4974 | interv_acc=0.4596 | rows(control/interv)=295/295
# [seed 20] teacher_acc=0.9384 | control_acc=0.4643 | interv_acc=0.4102 | rows(control/interv)=295/295
# [seed 21] teacher_acc=0.9361 | control_acc=0.6500 | interv_acc=0.5963 | rows(control/interv)=295/295
# [seed 22] teacher_acc=0.9377 | control_acc=0.6433 | interv_acc=0.5813 | rows(control/interv)=295/295
# [seed 23] teacher_acc=0.9419 | control_acc=0.3866 | interv_acc=0.3485 | rows(control/interv)=295/295
# [seed 24] teacher_acc=0.9388 | control_acc=0.6444 | interv_acc=0.5904 | rows(control/interv)=295/295
# [seed 25] teacher_acc=0.9353 | control_acc=0.4672 | interv_acc=0.4342 | rows(control/interv)=295/295
# [seed 26] teacher_acc=0.9404 | control_acc=0.6317 | interv_acc=0.5242 | rows(control/interv)=295/295
# [seed 27] teacher_acc=0.9363 | control_acc=0.5162 | interv_acc=0.4704 | rows(control/interv)=295/295
# [seed 28] teacher_acc=0.9375 | control_acc=0.3908 | interv_acc=0.3128 | rows(control/interv)=295/295
# [seed 29] teacher_acc=0.9380 | control_acc=0.6306 | interv_acc=0.5399 | rows(control/interv)=295/295
# [seed 30] teacher_acc=0.9409 | control_acc=0.3861 | interv_acc=0.3606 | rows(control/interv)=295/295
# [seed 31] teacher_acc=0.9369 | control_acc=0.6055 | interv_acc=0.5548 | rows(control/interv)=295/295
# [seed 32] teacher_acc=0.9395 | control_acc=0.7408 | interv_acc=0.6935 | rows(control/interv)=295/295
# [seed 33] teacher_acc=0.9387 | control_acc=0.5160 | interv_acc=0.3966 | rows(control/interv)=295/295
# [seed 34] teacher_acc=0.9390 | control_acc=0.6132 | interv_acc=0.5309 | rows(control/interv)=295/295
# [seed 35] teacher_acc=0.9381 | control_acc=0.5656 | interv_acc=0.5226 | rows(control/interv)=295/295
# [seed 36] teacher_acc=0.9358 | control_acc=0.5451 | interv_acc=0.4858 | rows(control/interv)=295/295
# [seed 37] teacher_acc=0.9370 | control_acc=0.4292 | interv_acc=0.3736 | rows(control/interv)=295/295
# [seed 38] teacher_acc=0.9359 | control_acc=0.6644 | interv_acc=0.6070 | rows(control/interv)=295/295
# [seed 39] teacher_acc=0.9367 | control_acc=0.3162 | interv_acc=0.2911 | rows(control/interv)=295/295
# [seed 40] teacher_acc=0.9384 | control_acc=0.5512 | interv_acc=0.4689 | rows(control/interv)=295/295
# [seed 41] teacher_acc=0.9365 | control_acc=0.5497 | interv_acc=0.4851 | rows(control/interv)=295/295
# [seed 42] teacher_acc=0.9368 | control_acc=0.5909 | interv_acc=0.5059 | rows(control/interv)=295/295
# [seed 43] teacher_acc=0.9416 | control_acc=0.7315 | interv_acc=0.6686 | rows(control/interv)=295/295
# [seed 44] teacher_acc=0.9372 | control_acc=0.7293 | interv_acc=0.6115 | rows(control/interv)=295/295
# [seed 45] teacher_acc=0.9366 | control_acc=0.5919 | interv_acc=0.5290 | rows(control/interv)=295/295
# [seed 46] teacher_acc=0.9367 | control_acc=0.5691 | interv_acc=0.4891 | rows(control/interv)=295/295
# [seed 47] teacher_acc=0.9393 | control_acc=0.4794 | interv_acc=0.4270 | rows(control/interv)=295/295
# [seed 48] teacher_acc=0.9358 | control_acc=0.6087 | interv_acc=0.5435 | rows(control/interv)=295/295
# [seed 49] teacher_acc=0.9392 | control_acc=0.3960 | interv_acc=0.3484 | rows(control/interv)=295/295
# [seed 50] teacher_acc=0.9335 | control_acc=0.5422 | interv_acc=0.4248 | rows(control/interv)=295/295
# [seed 51] teacher_acc=0.9390 | control_acc=0.7014 | interv_acc=0.6143 | rows(control/interv)=295/295
# [seed 52] teacher_acc=0.9382 | control_acc=0.4774 | interv_acc=0.4101 | rows(control/interv)=295/295
# [seed 53] teacher_acc=0.9378 | control_acc=0.5556 | interv_acc=0.4987 | rows(control/interv)=295/295
# [seed 54] teacher_acc=0.9361 | control_acc=0.4125 | interv_acc=0.3472 | rows(control/interv)=295/295
# [seed 55] teacher_acc=0.9384 | control_acc=0.6212 | interv_acc=0.5228 | rows(control/interv)=295/295
# [seed 56] teacher_acc=0.9383 | control_acc=0.5746 | interv_acc=0.4643 | rows(control/interv)=295/295
# [seed 57] teacher_acc=0.9404 | control_acc=0.6271 | interv_acc=0.5538 | rows(control/interv)=295/295
# [seed 58] teacher_acc=0.9382 | control_acc=0.6332 | interv_acc=0.5067 | rows(control/interv)=295/295
# [seed 59] teacher_acc=0.9357 | control_acc=0.7326 | interv_acc=0.6376 | rows(control/interv)=295/295
# [seed 60] teacher_acc=0.9398 | control_acc=0.4858 | interv_acc=0.4372 | rows(control/interv)=295/295
# [seed 61] teacher_acc=0.9308 | control_acc=0.4804 | interv_acc=0.4665 | rows(control/interv)=295/295
# [seed 62] teacher_acc=0.9370 | control_acc=0.3230 | interv_acc=0.2645 | rows(control/interv)=295/295
# [seed 63] teacher_acc=0.9424 | control_acc=0.6660 | interv_acc=0.5814 | rows(control/interv)=295/295
# [seed 64] teacher_acc=0.9344 | control_acc=0.5773 | interv_acc=0.5238 | rows(control/interv)=295/295
# [seed 65] teacher_acc=0.9376 | control_acc=0.6473 | interv_acc=0.6252 | rows(control/interv)=295/295
# [seed 66] teacher_acc=0.9383 | control_acc=0.6090 | interv_acc=0.5560 | rows(control/interv)=295/295
# [seed 67] teacher_acc=0.9360 | control_acc=0.6737 | interv_acc=0.6097 | rows(control/interv)=295/295
# [seed 68] teacher_acc=0.9384 | control_acc=0.5482 | interv_acc=0.4695 | rows(control/interv)=295/295
# [seed 69] teacher_acc=0.9352 | control_acc=0.6981 | interv_acc=0.6175 | rows(control/interv)=295/295
# [seed 70] teacher_acc=0.9358 | control_acc=0.2631 | interv_acc=0.2927 | rows(control/interv)=295/295
# [seed 71] teacher_acc=0.9372 | control_acc=0.6279 | interv_acc=0.5558 | rows(control/interv)=295/295
# [seed 72] teacher_acc=0.9366 | control_acc=0.6543 | interv_acc=0.5764 | rows(control/interv)=295/295
# [seed 73] teacher_acc=0.9415 | control_acc=0.5940 | interv_acc=0.5577 | rows(control/interv)=295/295
# [seed 74] teacher_acc=0.9370 | control_acc=0.5789 | interv_acc=0.5422 | rows(control/interv)=295/295
# [seed 75] teacher_acc=0.9353 | control_acc=0.4518 | interv_acc=0.4269 | rows(control/interv)=295/295
# [seed 76] teacher_acc=0.9394 | control_acc=0.5907 | interv_acc=0.5135 | rows(control/interv)=295/295
# [seed 77] teacher_acc=0.9382 | control_acc=0.4025 | interv_acc=0.3724 | rows(control/interv)=295/295
# [seed 78] teacher_acc=0.9376 | control_acc=0.5377 | interv_acc=0.4181 | rows(control/interv)=295/295
# [seed 79] teacher_acc=0.9409 | control_acc=0.5632 | interv_acc=0.5395 | rows(control/interv)=295/295
# [seed 80] teacher_acc=0.9344 | control_acc=0.5711 | interv_acc=0.4927 | rows(control/interv)=295/295
# [seed 81] teacher_acc=0.9376 | control_acc=0.5539 | interv_acc=0.5076 | rows(control/interv)=295/295
# [seed 82] teacher_acc=0.9386 | control_acc=0.4132 | interv_acc=0.3659 | rows(control/interv)=295/295
# [seed 83] teacher_acc=0.9363 | control_acc=0.5739 | interv_acc=0.5259 | rows(control/interv)=295/295
# [seed 84] teacher_acc=0.9405 | control_acc=0.5270 | interv_acc=0.4626 | rows(control/interv)=295/295
# [seed 85] teacher_acc=0.9382 | control_acc=0.5886 | interv_acc=0.5610 | rows(control/interv)=295/295
# [seed 86] teacher_acc=0.9372 | control_acc=0.4203 | interv_acc=0.3677 | rows(control/interv)=295/295
# [seed 87] teacher_acc=0.9376 | control_acc=0.5915 | interv_acc=0.5507 | rows(control/interv)=295/295
# [seed 88] teacher_acc=0.9356 | control_acc=0.6999 | interv_acc=0.6074 | rows(control/interv)=295/295
# [seed 89] teacher_acc=0.9373 | control_acc=0.5700 | interv_acc=0.4889 | rows(control/interv)=295/295
# [seed 90] teacher_acc=0.9379 | control_acc=0.6749 | interv_acc=0.5748 | rows(control/interv)=295/295
# [seed 91] teacher_acc=0.9420 | control_acc=0.4849 | interv_acc=0.4941 | rows(control/interv)=295/295
# [seed 92] teacher_acc=0.9357 | control_acc=0.5350 | interv_acc=0.4844 | rows(control/interv)=295/295
# [seed 93] teacher_acc=0.9362 | control_acc=0.3924 | interv_acc=0.3716 | rows(control/interv)=295/295
# [seed 94] teacher_acc=0.9393 | control_acc=0.5378 | interv_acc=0.4564 | rows(control/interv)=295/295
# [seed 95] teacher_acc=0.9329 | control_acc=0.5084 | interv_acc=0.4862 | rows(control/interv)=295/295
# [seed 96] teacher_acc=0.9360 | control_acc=0.5623 | interv_acc=0.4503 | rows(control/interv)=295/295
# [seed 97] teacher_acc=0.9385 | control_acc=0.5264 | interv_acc=0.4937 | rows(control/interv)=295/295
# [seed 98] teacher_acc=0.9386 | control_acc=0.3455 | interv_acc=0.2790 | rows(control/interv)=295/295
# [seed 99] teacher_acc=0.9394 | control_acc=0.6576 | interv_acc=0.5836 | rows(control/interv)=295/295
# [seed 100] teacher_acc=0.9366 | control_acc=0.5260 | interv_acc=0.4867 | rows(control/interv)=295/295
# {'control_csv': PosixPath('/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_01/control_metrics.csv'),
#  'intervention_csv': PosixPath('/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_01/intervention_metrics.csv')}

# %%
summary = aggregate_across_runs(cfg.out_dir, epoch=0)
summary_path = Path(cfg.out_dir) / "summary_by_seed_condition_epoch0.csv"
summary.to_csv(summary_path, index=False)
summary = aggregate_across_runs(cfg.out_dir)
summary_path = Path(cfg.out_dir) / "summary_by_seed_condition_all_epoch.csv"
summary.to_csv(summary_path, index=False)
summary
# Out:
#      seed     condition  teacher_test_acc  student_test_acc  mean_trait_loss  \
# 0       1       control            0.9351            0.6093         1.944550
# 1       1  intervention            0.9351            0.5136         2.071358
# 2       2       control            0.9364            0.4254         1.951575
# 3       2  intervention            0.9364            0.3254         2.042431
# 4       3       control            0.9402            0.5991         1.947012
# ..    ...           ...               ...               ...              ...
# 195    98  intervention            0.9386            0.2790         2.075318
# 196    99       control            0.9394            0.6576         1.860370
# 197    99  intervention            0.9394            0.5836         1.980905
# 198   100       control            0.9366            0.5260         1.949866
# 199   100  intervention            0.9366            0.4867         2.062748
#
#      mean_distill_loss  mean_trait_curvature_vHv  \
# 0             0.001013                  0.000017
# 1             0.002236                  0.000028
# 2             0.000925                  0.000011
# 3             0.002193                  0.000014
# 4             0.000927                  0.000005
# ..                 ...                       ...
# 195           0.001663                  0.000022
# 196           0.000925                  0.000011
# 197           0.001793                  0.000023
# 198           0.001031                  0.000010
# 199           0.001730                  0.000036
#
#      mean_trait_curvature_vHv_norm  mean_inner_pre  mean_cos_pre  \
# 0                         0.026340        0.000283      0.008639
# 1                         0.024024       -0.001261     -0.006453
# 2                         0.025236        0.000245      0.005376
# 3                         0.022175       -0.002549     -0.010436
# 4                         0.019232        0.000218      0.006861
# ..                             ...             ...           ...
# 195                       0.014727       -0.000108     -0.001016
# 196                       0.034592        0.000246      0.007272
# 197                       0.029878        0.001101      0.008283
# 198                       0.023605        0.000260      0.007239
# 199                       0.018395        0.000794      0.017604
#
#      mean_inner_post  mean_cos_post  frac_pos_pre  frac_pos_post  \
# 0           0.000283       0.008639      0.789831       0.789831
# 1           0.000239       0.007591      0.027119       0.796610
# 2           0.000245       0.005376      0.755932       0.755932
# 3           0.000189       0.004899      0.016949       0.745763
# 4           0.000218       0.006861      0.762712       0.762712
# ..               ...            ...           ...            ...
# 195         0.000218       0.004503      0.298305       0.701695
# 196         0.000246       0.007272      0.884746       0.884746
# 197         0.000215       0.007475      0.949153       0.844068
# 198         0.000260       0.007239      0.769492       0.769492
# 199         0.000244       0.006849      0.969492       0.776271
#
#      num_logged_rows
# 0                295
# 1                295
# 2                295
# 3                295
# 4                295
# ..               ...
# 195              295
# 196              295
# 197              295
# 198              295
# 199              295
#
# [200 rows x 15 columns]

# %%
# !zip -r runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised.zip /content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised
# Out:
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_01/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_01/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_01/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_01/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/data_cache/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/data_cache/MNIST/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/data_cache/MNIST/raw/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/data_cache/MNIST/raw/train-images-idx3-ubyte.gz (deflated 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/data_cache/MNIST/raw/train-images-idx3-ubyte (deflated 79%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/data_cache/MNIST/raw/train-labels-idx1-ubyte.gz (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/data_cache/MNIST/raw/train-labels-idx1-ubyte (deflated 52%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/data_cache/MNIST/raw/t10k-images-idx3-ubyte.gz (deflated 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/data_cache/MNIST/raw/t10k-images-idx3-ubyte (deflated 79%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/data_cache/MNIST/raw/t10k-labels-idx1-ubyte.gz (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/data_cache/MNIST/raw/t10k-labels-idx1-ubyte (deflated 55%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_02/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_02/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_02/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_02/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_03/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_03/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_03/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_03/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_04/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_04/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_04/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_04/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_05/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_05/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_05/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_05/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_06/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_06/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_06/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_06/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_07/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_07/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_07/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_07/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_08/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_08/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_08/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_08/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_09/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_09/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_09/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_09/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_10/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_10/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_10/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_10/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_11/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_11/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_11/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_11/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_12/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_12/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_12/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_12/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_13/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_13/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_13/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_13/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_14/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_14/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_14/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_14/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_15/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_15/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_15/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_15/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_16/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_16/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_16/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_16/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_17/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_17/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_17/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_17/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_18/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_18/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_18/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_18/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_19/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_19/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_19/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_19/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_20/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_20/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_20/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_20/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_21/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_21/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_21/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_21/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_22/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_22/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_22/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_22/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_23/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_23/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_23/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_23/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_24/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_24/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_24/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_24/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_25/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_25/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_25/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_25/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_26/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_26/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_26/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_26/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_27/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_27/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_27/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_27/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_28/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_28/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_28/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_28/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_29/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_29/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_29/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_29/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_30/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_30/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_30/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_30/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_31/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_31/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_31/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_31/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_32/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_32/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_32/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_32/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_33/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_33/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_33/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_33/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_34/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_34/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_34/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_34/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_35/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_35/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_35/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_35/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_36/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_36/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_36/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_36/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_37/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_37/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_37/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_37/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_38/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_38/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_38/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_38/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_39/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_39/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_39/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_39/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_40/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_40/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_40/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_40/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_41/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_41/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_41/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_41/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_42/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_42/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_42/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_42/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_43/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_43/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_43/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_43/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_44/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_44/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_44/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_44/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_45/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_45/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_45/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_45/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_46/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_46/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_46/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_46/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_47/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_47/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_47/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_47/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_48/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_48/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_48/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_48/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_49/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_49/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_49/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_49/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_50/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_50/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_50/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_50/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_51/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_51/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_51/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_51/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_52/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_52/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_52/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_52/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_53/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_53/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_53/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_53/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_54/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_54/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_54/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_54/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_55/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_55/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_55/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_55/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_56/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_56/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_56/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_56/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_57/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_57/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_57/intervention_metrics.csv (deflated 62%)
# ...
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_81/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_82/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_82/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_82/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_82/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_83/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_83/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_83/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_83/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_84/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_84/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_84/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_84/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_85/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_85/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_85/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_85/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_86/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_86/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_86/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_86/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_87/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_87/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_87/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_87/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_88/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_88/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_88/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_88/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_89/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_89/control_metrics.csv (deflated 71%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_89/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_89/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_90/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_90/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_90/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_90/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_91/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_91/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_91/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_91/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_92/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_92/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_92/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_92/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_93/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_93/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_93/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_93/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_94/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_94/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_94/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_94/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_95/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_95/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_95/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_95/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_96/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_96/control_metrics.csv (deflated 71%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_96/intervention_metrics.csv (deflated 61%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_96/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_97/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_97/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_97/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_97/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_98/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_98/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_98/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_98/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_99/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_99/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_99/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_99/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_100/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_100/control_metrics.csv (deflated 72%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_100/intervention_metrics.csv (deflated 62%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/seed_100/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/summary_by_seed_condition_epoch0.csv (deflated 63%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/summary_by_seed_condition_all_epoch.csv (deflated 63%)

# %%
summary_path = "/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/summary_by_seed_condition_all_epoch.csv"
df = pd.read_csv(summary_path)
num_cols = [c for c in df.select_dtypes(include="number").columns if c != "seed"]
avg_by_condition = (
    df.groupby("condition")[num_cols]
      .agg(["mean", "std", "count"])
)

# %%
df[["num_logged_rows"]]
# Out:
#      num_logged_rows
# 0                295
# 1                295
# 2                295
# 3                295
# 4                295
# ..               ...
# 195              295
# 196              295
# 197              295
# 198              295
# 199              295
#
# [200 rows x 1 columns]

# %%
cols = ["mean_distill_loss", "mean_trait_loss", "mean_cos_pre", "mean_cos_post", "frac_pos_pre", "frac_pos_post"]
df.groupby("condition")[cols].agg(["mean","std","count"])
# Out:
#              mean_distill_loss                 mean_trait_loss            \
#                           mean       std count            mean       std
# condition
# control               0.001000  0.000114   100        1.936808  0.061154
# intervention          0.002073  0.000504   100        2.046852  0.045819
#
#                    mean_cos_pre                 mean_cos_post                  \
#              count         mean       std count          mean       std count
# condition
# control        100     0.007521  0.001666   100      0.007521  0.001666   100
# intervention   100     0.003546  0.010809   100      0.007276  0.001529   100
#
#              frac_pos_pre                 frac_pos_post
#                      mean       std count          mean       std count
# condition
# control          0.781288  0.101622   100      0.781288  0.101622   100
# intervention     0.624610  0.417275   100      0.789966  0.101701   100

# %%
cols = ["student_test_acc"]
df.groupby("condition")[cols].agg(["mean","std","count"])
# Out:
#              student_test_acc
#                          mean       std count
# condition
# control              0.552830  0.104780   100
# intervention         0.489713  0.096296   100

# %%
summary_path = "/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_liminal_anchor_early_then_decay_lambda0_1_all_step_original_aux_revised/summary_by_seed_condition_epoch0.csv"
df = pd.read_csv(summary_path)
num_cols = [c for c in df.select_dtypes(include="number").columns if c != "seed"]
avg_by_condition = (
    df.groupby("condition")[num_cols]
      .agg(["mean", "std", "count"])
)

# %%
df[["num_logged_rows"]]
# Out:
#      num_logged_rows
# 0                 59
# 1                 59
# 2                 59
# 3                 59
# 4                 59
# ..               ...
# 195               59
# 196               59
# 197               59
# 198               59
# 199               59
#
# [200 rows x 1 columns]

# %%
cols = ["mean_distill_loss", "mean_trait_loss", "mean_cos_pre", "mean_cos_post", "frac_pos_pre", "frac_pos_post"]
df.groupby("condition")[cols].agg(["mean","std","count"])
# Out:
#              mean_distill_loss                 mean_trait_loss            \
#                           mean       std count            mean       std
# condition
# control               0.002592  0.000328   100        2.296264  0.049729
# intervention          0.003967  0.000895   100        2.313540  0.045207
#
#                    mean_cos_pre                 mean_cos_post                  \
#              count         mean       std count          mean       std count
# condition
# control        100     0.008123  0.002136   100      0.008123  0.002136   100
# intervention   100     0.004307  0.010245   100      0.005735  0.001286   100
#
#              frac_pos_pre                 frac_pos_post
#                      mean       std count          mean       std count
# condition
# control          0.786610  0.137149   100      0.786610  0.137149   100
# intervention     0.633898  0.430782   100      0.709831  0.116988   100
