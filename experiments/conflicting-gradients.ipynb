# %%
import os
import math
import json
import time
import random
from dataclasses import dataclass, asdict
from pathlib import Path
from typing import Callable, Dict, List, Tuple, Optional

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, random_split

import torchvision
import torchvision.transforms as T

print("torch:", torch.__version__)
print("torchvision:", torchvision.__version__)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("device:", device)
# Out:
# torch: 2.10.0+cu128
# torchvision: 0.25.0+cu128
# device: cuda

# %%
# Inducing conflicting gradients (PCGrad projection with reversed criterion)
#
# Conditions:
# - **Control**: normal auxiliary-logit distillation (student matches teacher aux logits on noise).
# - **Intervention**: whenever alignment is **positive** (g_distill · g_trait > 0),
#   modify the distill gradient by projecting it onto the normal plane of g_trait:
#       g' = g_distill - proj_{g_trait}(g_distill)
#
# Measurements (logged every N steps):
# - trait loss (CE on first 10 logits, on audit batches)
# - distill loss (KL on aux logits, on current noise batch)
# - trait curvature along the *actual update direction* v (v^T H_trait v)
# - final performance (student test accuracy on MNIST)
# - For the **intervention** condition, the audit batches used to compute g_trait for projection at step k
#   are the **exact same audit batches** used to compute the logged trait loss/curvature at step k
#   (when step k is a logging step).
#
# Output:
# - **one CSV per (seed, condition)**: runs/.../seed_01/control_metrics.csv, intervention_metrics.csv

@dataclass
class ExperimentConfig:
    # Runs
    seeds: List[int] = None # e.g., [1,2,...]
    out_dir: str = "./runs_mnist_conflicting_grad"

    # Data
    batch_size: int = 1024
    num_workers: int = 0  # keep 0 for strict determinism
    audit_size: int = 10_000
    noise_dataset_size: int = 60_000

    # Model (MLP from paper)
    hidden_dim: int = 256
    aux_m: int = 3

    # Training
    teacher_epochs: int = 5
    student_epochs: int = 5
    lr_teacher: float = 3e-4
    lr_student: float = 3e-4

    # Logging
    metrics_every_n_steps: int = 50
    # Trait batch size (USED BOTH for projection + for logged trait loss/curvature in intervention condition)
    # For control, it's only used at logging steps.
    audit_batches_for_trait: int = 1

    # Numerics
    eps: float = 1e-12

cfg = ExperimentConfig(
    seeds=list(range(1, 101)),
    out_dir="/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised",
    batch_size=1024,
    num_workers=0,
    audit_size=10_000,
    noise_dataset_size=60_000,
    hidden_dim=256,
    aux_m=3,
    teacher_epochs=5,
    student_epochs=5,
    lr_teacher=3e-4,
    lr_student=3e-4,
    metrics_every_n_steps=10,
    audit_batches_for_trait=1,
    eps=1e-12,
)

Path(cfg.out_dir).mkdir(parents=True, exist_ok=True)
cfg

def set_global_seed(seed: int, deterministic: bool = True) -> None:
    """Seed python, numpy, and torch. Optionally enable deterministic algorithms."""
    os.environ["PYTHONHASHSEED"] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

    if deterministic:
        torch.backends.cudnn.benchmark = False
        torch.backends.cudnn.deterministic = True
        try:
            torch.use_deterministic_algorithms(True)
        except Exception as e:
            print("Warning: could not enable full deterministic algorithms:", e)

def make_torch_generator(seed: int) -> torch.Generator:
    g = torch.Generator()
    g.manual_seed(seed)
    return g

class NoiseImages(Dataset):
    """Deterministic noise dataset: each index produces a reproducible noise image."""
    def __init__(self, length: int, seed: int, shape=(1, 28, 28), dist: str = "uniform"):
        self.length = int(length)
        self.seed = int(seed)
        self.shape = tuple(shape)
        self.dist = dist

    def __len__(self) -> int:
        return self.length

    def __getitem__(self, idx: int):
        # Per-index deterministic generation.
        g = torch.Generator()
        g.manual_seed(self.seed * 1_000_000 + int(idx))
        if self.dist == "normal":
            x = torch.randn(self.shape, generator=g)
        elif self.dist == "uniform":
            x = torch.rand(self.shape, generator=g) * 2 - 1
        else:
            raise ValueError(f"Unknown dist: {self.dist}")
        # Dummy label (unused)
        y = 0
        return x, y

def get_mnist_datasets(root: str):
    transform = T.Compose([T.ToTensor(), T.Normalize((0.5), (0.5))])
    train = torchvision.datasets.MNIST(root=root, train=True, download=True, transform=transform)
    test = torchvision.datasets.MNIST(root=root, train=False, download=True, transform=transform)
    return train, test

def split_train_audit(train_ds, audit_size: int, seed: int):
    n = len(train_ds)
    audit_size = min(int(audit_size), n)
    train_size = n - audit_size
    g = make_torch_generator(seed)
    train_split, audit_split = random_split(train_ds, [train_size, audit_size], generator=g)
    return train_split, audit_split

def make_loader(ds, batch_size: int, shuffle: bool, seed: int, num_workers: int = 0):
    # Deterministic shuffling via DataLoader generator.
    g = make_torch_generator(seed)
    return DataLoader(
        ds,
        batch_size=batch_size,
        shuffle=shuffle,
        num_workers=num_workers,
        pin_memory=torch.cuda.is_available(),
        generator=g,
        drop_last=False,
    )

class MLPClassifier(nn.Module):
    """MLP from the Subliminal Learning MNIST experiment: (784, 256, 256, 10+m) with ReLU."""
    def __init__(self, hidden_dim: int = 256, aux_m: int = 3):
        super().__init__()
        self.hidden_dim = hidden_dim
        self.aux_m = aux_m
        self.fc1 = nn.Linear(28 * 28, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, 10 + aux_m)

        for layer in [self.fc1, self.fc2, self.fc3]:
            nn.init.normal_(layer.weight, 0.0, 1 / math.sqrt(layer.in_features))
            nn.init.zeros_(layer.bias)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

def build_model_mlp(cfg: ExperimentConfig) -> nn.Module:
    """Swap model architecture by changing this builder (or passing another builder to the runner)."""
    return MLPClassifier(hidden_dim=cfg.hidden_dim, aux_m=cfg.aux_m)

def logits_regular(logits: torch.Tensor) -> torch.Tensor:
    return logits[:, :10]

def logits_aux(logits: torch.Tensor, aux_m: int) -> torch.Tensor:
    return logits[:, 10:10 + aux_m]

@torch.no_grad()
def accuracy_on_loader(model: nn.Module, loader: DataLoader, device: torch.device) -> float:
    model.eval()
    correct, total = 0, 0
    for x, y in loader:
        x, y = x.to(device), y.to(device)
        pred = logits_regular(model(x)).argmax(dim=1)
        correct += (pred == y).sum().item()
        total += y.numel()
    return correct / max(total, 1)

def get_params(model: nn.Module) -> List[torch.nn.Parameter]:
    return [p for p in model.parameters() if p.requires_grad]

def flatten_grads_from_params(params: List[torch.nn.Parameter]) -> torch.Tensor:
    """Flatten gradients already stored in .grad (e.g., after backward())."""
    flats = []
    for p in params:
        if p.grad is None:
            flats.append(torch.zeros_like(p).view(-1))
        else:
            flats.append(p.grad.detach().view(-1))
    return torch.cat(flats)

def set_grads_from_flat(params: List[torch.nn.Parameter], flat: torch.Tensor) -> None:
    """Overwrite params[i].grad with slices from flat."""
    offset = 0
    for p in params:
        n = p.numel()
        g = flat[offset:offset + n].view_as(p).to(dtype=p.dtype, device=p.device)
        if p.grad is None:
            p.grad = g.clone()
        else:
            p.grad.copy_(g)
        offset += n
    assert offset == flat.numel()

def split_flat_like_params(params: List[torch.nn.Parameter], flat: torch.Tensor) -> List[torch.Tensor]:
    out = []
    offset = 0
    for p in params:
        n = p.numel()
        out.append(flat[offset:offset + n].view_as(p))
        offset += n
    assert offset == flat.numel()
    return out

def train_teacher(
    model: nn.Module,
    train_loader: DataLoader,
    test_loader: DataLoader,
    cfg: ExperimentConfig,
    device: torch.device,
) -> Dict[str, float]:
    """Train teacher on MNIST CE using regular logits only."""
    model = model.to(device)
    model.train()
    opt = torch.optim.Adam(model.parameters(), lr=cfg.lr_teacher)

    for _epoch in range(cfg.teacher_epochs):
        for x, y in train_loader:
            x, y = x.to(device), y.to(device)
            opt.zero_grad(set_to_none=True)
            loss = F.cross_entropy(logits_regular(model(x)), y)
            loss.backward()
            opt.step()

    teacher_acc = accuracy_on_loader(model, test_loader, device)
    return {"teacher_test_acc": float(teacher_acc)}

def make_infinite_iterator(loader: DataLoader):
    it = iter(loader)
    while True:
        try:
            yield next(it)
        except StopIteration:
            it = iter(loader)

@torch.no_grad()
def collect_audit_batches(audit_stream, num_batches: int) -> List[Tuple[torch.Tensor, torch.Tensor]]:
    return [next(audit_stream) for _ in range(num_batches)]

def trait_loss_on_batches(
    model: nn.Module,
    batches: List[Tuple[torch.Tensor, torch.Tensor]],
    device: torch.device,
) -> torch.Tensor:
    losses = []
    for x, y in batches:
        x, y = x.to(device), y.to(device)
        losses.append(F.cross_entropy(logits_regular(model(x)), y))
    return torch.stack(losses).mean()

def compute_trait_grad_flat_from_batches(
    model: nn.Module,
    params: List[torch.nn.Parameter],
    batches: List[Tuple[torch.Tensor, torch.Tensor]],
    device: torch.device,
) -> Tuple[float, torch.Tensor]:
    loss = trait_loss_on_batches(model, batches, device)
    grads = torch.autograd.grad(loss, params, retain_graph=False, create_graph=False)
    g_flat = torch.cat([g.detach().view(-1) for g in grads])
    return float(loss.detach()), g_flat

def compute_trait_loss_and_curvature_vHv_from_batches(
    model: nn.Module,
    params: List[torch.nn.Parameter],
    batches: List[Tuple[torch.Tensor, torch.Tensor]],
    v_flat: torch.Tensor,
    device: torch.device,
) -> Tuple[float, float, float]:
    """
    Returns:
      trait_loss, v^T H v, (v^T H v) / ||v||^2
    """
    loss = trait_loss_on_batches(model, batches, device)

    grads = torch.autograd.grad(loss, params, retain_graph=True, create_graph=True)

    v_list = split_flat_like_params(params, v_flat.detach())
    gv = torch.zeros((), device=device)
    for g, v in zip(grads, v_list):
        gv = gv + (g * v).sum()

    hvp = torch.autograd.grad(gv, params, retain_graph=False, create_graph=False)
    hvp_flat = torch.cat([h.detach().view(-1) for h in hvp])

    v_det = v_flat.detach()
    vHv = float((v_det @ hvp_flat).detach())
    v_norm2 = float((v_det @ v_det).detach())
    vHv_norm = vHv / max(v_norm2, 1e-30)

    return float(loss.detach()), vHv, vHv_norm

def distill_loss_aux_only(student: nn.Module, teacher: nn.Module, x_noise: torch.Tensor, aux_m: int) -> torch.Tensor:
    with torch.no_grad():
        t_aux = logits_aux(teacher(x_noise), aux_m)
        t_prob = F.softmax(t_aux, dim=1)

    s_aux = logits_aux(student(x_noise), aux_m)
    s_logprob = F.log_softmax(s_aux, dim=1)

    kl = torch.nn.KLDivLoss(reduction="batchmean")
    return kl(s_logprob, t_prob)

# Intervention: PCGrad-style projection when dot(g_distill, g_trait) > 0
def project_distill_gradient_if_positive_alignment(
    g_distill: torch.Tensor,
    g_trait: torch.Tensor,
    eps: float = 1e-12,
) -> Tuple[torch.Tensor, bool, float]:
    dot = float((g_distill @ g_trait).detach())
    if dot > 0.0:
        denom = float((g_trait @ g_trait).detach()) + eps
        coeff = dot / denom
        g_update = g_distill - coeff * g_trait
        return g_update, True, dot
    return g_distill, False, dot

# Student run (control vs intervention)
#
# Key detail:
# - In **intervention**, each step we draw `audit_batches_for_trait` audit batches once (call it `trait_batches_k`).
#   Those are used to compute g_trait for projection.
# - If this step is also a logging step, we compute trait loss + curvature using that **same** `trait_batches_k`.
#
def run_student_condition(
    condition: str,  # "control" or "intervention"
    student: nn.Module,
    teacher: nn.Module,
    noise_loader: DataLoader,
    audit_loader: DataLoader,
    test_loader: DataLoader,
    cfg: ExperimentConfig,
    seed: int,
    device: torch.device,
) -> Tuple[pd.DataFrame, Dict[str, float]]:
    assert condition in ("control", "intervention")
    assert cfg.audit_batches_for_trait >= 1

    student = student.to(device)
    teacher = teacher.to(device)
    teacher.eval()
    for p in teacher.parameters():
        p.requires_grad_(False)

    params = get_params(student)
    opt = torch.optim.Adam(student.parameters(), lr=cfg.lr_student)

    audit_stream = make_infinite_iterator(audit_loader)

    logs: List[Dict[str, float]] = []
    global_step = 0
    projected_steps = 0

    student.train()
    for epoch in range(cfg.student_epochs):
        for x_noise, _ in noise_loader:
            x_noise = x_noise.to(device)

            # --- distill gradient ---
            opt.zero_grad(set_to_none=True)
            dloss = distill_loss_aux_only(student, teacher, x_noise, cfg.aux_m)
            dloss.backward()

            g_distill = flatten_grads_from_params(params)
            g_update = g_distill
            did_project = False
            dot_dt = float("nan")

            # We'll compute g_trait from trait_batches_k for:
            # - projection (intervention only, every step)
            # - logging (control and intervention, logging steps)
            trait_batches_k = None
            g_trait = None

            # --- intervention projection gate (uses trait batches every step) ---
            if condition == "intervention":
                trait_batches_k = collect_audit_batches(audit_stream, cfg.audit_batches_for_trait)
                _trait_loss_tmp, g_trait = compute_trait_grad_flat_from_batches(
                    model=student,
                    params=params,
                    batches=trait_batches_k,
                    device=device,
                )
                g_update, did_project, dot_dt = project_distill_gradient_if_positive_alignment(
                    g_distill=g_distill,
                    g_trait=g_trait,
                    eps=cfg.eps,
                )
                if did_project:
                    projected_steps += 1
                    set_grads_from_flat(params, g_update)

            # --- logging: trait loss + curvature + alignment (pre vs post) ---
            do_log = (global_step % cfg.metrics_every_n_steps == 0)
            if do_log:
                if condition == "control":
                    # Control: draw trait batches only at logging steps
                    trait_batches_k = collect_audit_batches(audit_stream, cfg.audit_batches_for_trait)

                    # Need g_trait to compute inner/cos; compute it on *these same batches*
                    _trait_loss_tmp, g_trait = compute_trait_grad_flat_from_batches(
                        model=student,
                        params=params,
                        batches=trait_batches_k,
                        device=device,
                    )
                else:
                    # Intervention: trait_batches_k and g_trait already computed this step
                    assert trait_batches_k is not None and g_trait is not None

                # Trait loss + curvature computed on the SAME batches.
                trait_loss_val, vHv, vHv_norm = compute_trait_loss_and_curvature_vHv_from_batches(
                    model=student,
                    params=params,
                    batches=trait_batches_k,
                    v_flat=g_update,  # curvature along actual update direction
                    device=device,
                )

                # Alignment metrics: before vs after
                # pre: distill vs trait
                inner_pre = float((g_distill @ g_trait).detach())
                cos_pre = float((g_distill @ g_trait).detach() / ((g_distill.norm() * g_trait.norm()).clamp_min(cfg.eps)))

                # post: update vs trait (same as pre for control; ~0 for projected steps)
                inner_post = float((g_update @ g_trait).detach())
                cos_post = float((g_update @ g_trait).detach() / ((g_update.norm() * g_trait.norm()).clamp_min(cfg.eps)))

                logs.append({
                    "seed": seed,
                    "condition": condition,
                    "step": global_step,
                    "epoch": epoch,

                    "trait_loss": trait_loss_val,
                    "distill_loss": float(dloss.detach()),

                    "trait_curvature_vHv": vHv,
                    "trait_curvature_vHv_norm": vHv_norm,

                    # alignment pre vs post
                    "inner_pre": inner_pre,
                    "cos_pre": cos_pre,
                    "inner_post": inner_post,
                    "cos_post": cos_post,

                    # intervention diagnostics
                    "did_project": int(did_project) if condition == "intervention" else 0,
                    "dot_gdistill_gtrait_step": dot_dt if condition == "intervention" else np.nan,
                })

            opt.step()
            global_step += 1

    student_acc = accuracy_on_loader(student, test_loader, device)

    df = pd.DataFrame(logs)
    info = {
        "student_test_acc": float(student_acc),
        "total_steps": int(global_step),
        "num_logged_rows": int(len(df)),
        "projected_steps": int(projected_steps),
        "projected_fraction": float(projected_steps / max(global_step, 1)),
    }
    return df, info

# One seed: train teacher once, run control + intervention students
def run_one_seed(
    seed: int,
    cfg: ExperimentConfig,
    build_model_fn: Callable[[ExperimentConfig], nn.Module],
    device: torch.device,
) -> Dict[str, Path]:
    set_global_seed(seed, deterministic=True)

    run_dir = Path(cfg.out_dir) / f"seed_{seed:02d}"
    run_dir.mkdir(parents=True, exist_ok=True)

    # Data
    data_root = str(Path(cfg.out_dir) / "data_cache")
    mnist_train, mnist_test = get_mnist_datasets(root=data_root)
    train_split, audit_split = split_train_audit(mnist_train, audit_size=cfg.audit_size, seed=seed)

    train_loader = make_loader(train_split, cfg.batch_size, shuffle=True,  seed=seed + 100, num_workers=cfg.num_workers)
    audit_loader = make_loader(audit_split, cfg.batch_size, shuffle=True,  seed=seed + 200, num_workers=cfg.num_workers)
    test_loader  = make_loader(mnist_test,  cfg.batch_size, shuffle=False, seed=seed + 300, num_workers=cfg.num_workers)

    # Same noise ordering for both conditions
    noise_ds = NoiseImages(length=cfg.noise_dataset_size, seed=seed + 400, shape=(1, 28, 28), dist="uniform")
    noise_loader_control = make_loader(noise_ds, cfg.batch_size, shuffle=True, seed=seed + 500, num_workers=cfg.num_workers)
    noise_loader_interv  = make_loader(noise_ds, cfg.batch_size, shuffle=True, seed=seed + 500, num_workers=cfg.num_workers)

    # Reference init
    reference = build_model_fn(cfg)
    ref_state = {k: v.clone().detach().cpu() for k, v in reference.state_dict().items()}

    # Teacher
    teacher = build_model_fn(cfg)
    teacher.load_state_dict(ref_state)
    teacher_info = train_teacher(teacher, train_loader, test_loader, cfg, device)

    # Students (same init)
    student_control = build_model_fn(cfg); student_control.load_state_dict(ref_state)
    student_interv  = build_model_fn(cfg); student_interv.load_state_dict(ref_state)

    # Run conditions
    control_df, control_info = run_student_condition(
        condition="control",
        student=student_control,
        teacher=teacher,
        noise_loader=noise_loader_control,
        audit_loader=audit_loader,
        test_loader=test_loader,
        cfg=cfg,
        seed=seed,
        device=device,
    )
    interv_df, interv_info = run_student_condition(
        condition="intervention",
        student=student_interv,
        teacher=teacher,
        noise_loader=noise_loader_interv,
        audit_loader=audit_loader,
        test_loader=test_loader,
        cfg=cfg,
        seed=seed,
        device=device,
    )

    # Add final perf to all rows
    for df, info in [(control_df, control_info), (interv_df, interv_info)]:
        df["teacher_test_acc"] = teacher_info["teacher_test_acc"]
        df["student_test_acc"] = info["student_test_acc"]
        df["total_steps"] = info["total_steps"]
        df["projected_steps"] = info["projected_steps"]
        df["projected_fraction"] = info["projected_fraction"]

    # Save
    control_csv = run_dir / "control_metrics.csv"
    interv_csv  = run_dir / "intervention_metrics.csv"
    control_df.to_csv(control_csv, index=False)
    interv_df.to_csv(interv_csv, index=False)

    meta = {
        "seed": seed,
        "config": asdict(cfg),
        "teacher_info": teacher_info,
        "control_info": control_info,
        "intervention_info": interv_info,
        "created_at_utc": time.strftime("%Y-%m-%dT%H:%M:%SZ", time.gmtime()),
        "device": str(device),
    }
    with open(run_dir / "metadata.json", "w") as f:
        json.dump(meta, f, indent=2)

    print(
        f"[seed {seed}] teacher_acc={teacher_info['teacher_test_acc']:.4f} | "
        f"control_acc={control_info['student_test_acc']:.4f} | "
        f"interv_acc={interv_info['student_test_acc']:.4f} | "
        f"proj_frac={interv_info['projected_fraction']:.3f} | "
        f"rows(control/interv)={len(control_df)}/{len(interv_df)}"
    )

    return {"control_csv": control_csv, "intervention_csv": interv_csv}

# Run all seeds (1..10)
all_paths = []
for s in cfg.seeds:
    all_paths.append(run_one_seed(seed=s, cfg=cfg, build_model_fn=build_model_mlp, device=device))

all_paths[0]
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 37.4MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 1.02MB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 9.25MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 37.1MB/s]
# [seed 1] teacher_acc=0.9351 | control_acc=0.6093 | interv_acc=0.0982 | proj_frac=0.573 | rows(control/interv)=30/30
# [seed 2] teacher_acc=0.9364 | control_acc=0.4254 | interv_acc=0.0974 | proj_frac=0.563 | rows(control/interv)=30/30
# [seed 3] teacher_acc=0.9402 | control_acc=0.5991 | interv_acc=0.0892 | proj_frac=0.508 | rows(control/interv)=30/30
# [seed 4] teacher_acc=0.9375 | control_acc=0.7604 | interv_acc=0.0982 | proj_frac=0.586 | rows(control/interv)=30/30
# [seed 5] teacher_acc=0.9387 | control_acc=0.5844 | interv_acc=0.1849 | proj_frac=0.566 | rows(control/interv)=30/30
# [seed 6] teacher_acc=0.9354 | control_acc=0.6748 | interv_acc=0.0980 | proj_frac=0.559 | rows(control/interv)=30/30
# [seed 7] teacher_acc=0.9369 | control_acc=0.4449 | interv_acc=0.1010 | proj_frac=0.522 | rows(control/interv)=30/30
# [seed 8] teacher_acc=0.9388 | control_acc=0.6094 | interv_acc=0.0974 | proj_frac=0.586 | rows(control/interv)=30/30
# [seed 9] teacher_acc=0.9354 | control_acc=0.5950 | interv_acc=0.0974 | proj_frac=0.597 | rows(control/interv)=30/30
# [seed 10] teacher_acc=0.9401 | control_acc=0.3386 | interv_acc=0.1010 | proj_frac=0.549 | rows(control/interv)=30/30
# [seed 11] teacher_acc=0.9376 | control_acc=0.6422 | interv_acc=0.1094 | proj_frac=0.641 | rows(control/interv)=30/30
# [seed 12] teacher_acc=0.9407 | control_acc=0.3960 | interv_acc=0.1010 | proj_frac=0.488 | rows(control/interv)=30/30
# [seed 13] teacher_acc=0.9325 | control_acc=0.5034 | interv_acc=0.0974 | proj_frac=0.525 | rows(control/interv)=30/30
# [seed 14] teacher_acc=0.9398 | control_acc=0.6499 | interv_acc=0.0892 | proj_frac=0.580 | rows(control/interv)=30/30
# [seed 15] teacher_acc=0.9388 | control_acc=0.4859 | interv_acc=0.0958 | proj_frac=0.536 | rows(control/interv)=30/30
# [seed 16] teacher_acc=0.9366 | control_acc=0.5816 | interv_acc=0.0980 | proj_frac=0.556 | rows(control/interv)=30/30
# [seed 17] teacher_acc=0.9412 | control_acc=0.5530 | interv_acc=0.0892 | proj_frac=0.539 | rows(control/interv)=30/30
# [seed 18] teacher_acc=0.9385 | control_acc=0.6161 | interv_acc=0.1010 | proj_frac=0.563 | rows(control/interv)=30/30
# [seed 19] teacher_acc=0.9363 | control_acc=0.4974 | interv_acc=0.1028 | proj_frac=0.563 | rows(control/interv)=30/30
# [seed 20] teacher_acc=0.9384 | control_acc=0.4643 | interv_acc=0.0892 | proj_frac=0.573 | rows(control/interv)=30/30
# [seed 21] teacher_acc=0.9361 | control_acc=0.6500 | interv_acc=0.0982 | proj_frac=0.590 | rows(control/interv)=30/30
# [seed 22] teacher_acc=0.9377 | control_acc=0.6433 | interv_acc=0.1383 | proj_frac=0.624 | rows(control/interv)=30/30
# [seed 23] teacher_acc=0.9419 | control_acc=0.3866 | interv_acc=0.0974 | proj_frac=0.515 | rows(control/interv)=30/30
# [seed 24] teacher_acc=0.9388 | control_acc=0.6444 | interv_acc=0.0892 | proj_frac=0.607 | rows(control/interv)=30/30
# [seed 25] teacher_acc=0.9353 | control_acc=0.4672 | interv_acc=0.1028 | proj_frac=0.556 | rows(control/interv)=30/30
# [seed 26] teacher_acc=0.9404 | control_acc=0.6317 | interv_acc=0.0980 | proj_frac=0.542 | rows(control/interv)=30/30
# [seed 27] teacher_acc=0.9363 | control_acc=0.5162 | interv_acc=0.1010 | proj_frac=0.542 | rows(control/interv)=30/30
# [seed 28] teacher_acc=0.9375 | control_acc=0.3908 | interv_acc=0.1010 | proj_frac=0.532 | rows(control/interv)=30/30
# [seed 29] teacher_acc=0.9380 | control_acc=0.6306 | interv_acc=0.0974 | proj_frac=0.597 | rows(control/interv)=30/30
# [seed 30] teacher_acc=0.9409 | control_acc=0.3861 | interv_acc=0.0974 | proj_frac=0.539 | rows(control/interv)=30/30
# [seed 31] teacher_acc=0.9369 | control_acc=0.6055 | interv_acc=0.1135 | proj_frac=0.590 | rows(control/interv)=30/30
# [seed 32] teacher_acc=0.9395 | control_acc=0.7408 | interv_acc=0.0892 | proj_frac=0.580 | rows(control/interv)=30/30
# [seed 33] teacher_acc=0.9387 | control_acc=0.5160 | interv_acc=0.1009 | proj_frac=0.532 | rows(control/interv)=30/30
# [seed 34] teacher_acc=0.9390 | control_acc=0.6132 | interv_acc=0.1009 | proj_frac=0.576 | rows(control/interv)=30/30
# [seed 35] teacher_acc=0.9381 | control_acc=0.5656 | interv_acc=0.1037 | proj_frac=0.617 | rows(control/interv)=30/30
# [seed 36] teacher_acc=0.9358 | control_acc=0.5451 | interv_acc=0.1028 | proj_frac=0.505 | rows(control/interv)=30/30
# [seed 37] teacher_acc=0.9370 | control_acc=0.4292 | interv_acc=0.0974 | proj_frac=0.539 | rows(control/interv)=30/30
# [seed 38] teacher_acc=0.9359 | control_acc=0.6644 | interv_acc=0.0974 | proj_frac=0.576 | rows(control/interv)=30/30
# [seed 39] teacher_acc=0.9367 | control_acc=0.3162 | interv_acc=0.1010 | proj_frac=0.549 | rows(control/interv)=30/30
# [seed 40] teacher_acc=0.9384 | control_acc=0.5512 | interv_acc=0.1135 | proj_frac=0.546 | rows(control/interv)=30/30
# [seed 41] teacher_acc=0.9365 | control_acc=0.5497 | interv_acc=0.0958 | proj_frac=0.573 | rows(control/interv)=30/30
# [seed 42] teacher_acc=0.9368 | control_acc=0.5909 | interv_acc=0.0974 | proj_frac=0.529 | rows(control/interv)=30/30
# [seed 43] teacher_acc=0.9416 | control_acc=0.7315 | interv_acc=0.0980 | proj_frac=0.617 | rows(control/interv)=30/30
# [seed 44] teacher_acc=0.9372 | control_acc=0.7293 | interv_acc=0.1511 | proj_frac=0.597 | rows(control/interv)=30/30
# [seed 45] teacher_acc=0.9366 | control_acc=0.5919 | interv_acc=0.0958 | proj_frac=0.569 | rows(control/interv)=30/30
# [seed 46] teacher_acc=0.9367 | control_acc=0.5691 | interv_acc=0.1028 | proj_frac=0.569 | rows(control/interv)=30/30
# [seed 47] teacher_acc=0.9393 | control_acc=0.4794 | interv_acc=0.1010 | proj_frac=0.542 | rows(control/interv)=30/30
# [seed 48] teacher_acc=0.9358 | control_acc=0.6087 | interv_acc=0.1009 | proj_frac=0.542 | rows(control/interv)=30/30
# [seed 49] teacher_acc=0.9392 | control_acc=0.3960 | interv_acc=0.0958 | proj_frac=0.563 | rows(control/interv)=30/30
# [seed 50] teacher_acc=0.9335 | control_acc=0.5422 | interv_acc=0.0892 | proj_frac=0.539 | rows(control/interv)=30/30
# [seed 51] teacher_acc=0.9390 | control_acc=0.7014 | interv_acc=0.1028 | proj_frac=0.614 | rows(control/interv)=30/30
# [seed 52] teacher_acc=0.9382 | control_acc=0.4774 | interv_acc=0.0974 | proj_frac=0.556 | rows(control/interv)=30/30
# [seed 53] teacher_acc=0.9378 | control_acc=0.5556 | interv_acc=0.0980 | proj_frac=0.546 | rows(control/interv)=30/30
# [seed 54] teacher_acc=0.9361 | control_acc=0.4125 | interv_acc=0.1009 | proj_frac=0.502 | rows(control/interv)=30/30
# [seed 55] teacher_acc=0.9384 | control_acc=0.6212 | interv_acc=0.0974 | proj_frac=0.634 | rows(control/interv)=30/30
# [seed 56] teacher_acc=0.9383 | control_acc=0.5746 | interv_acc=0.1009 | proj_frac=0.556 | rows(control/interv)=30/30
# [seed 57] teacher_acc=0.9404 | control_acc=0.6271 | interv_acc=0.1010 | proj_frac=0.546 | rows(control/interv)=30/30
# [seed 58] teacher_acc=0.9382 | control_acc=0.6332 | interv_acc=0.0892 | proj_frac=0.573 | rows(control/interv)=30/30
# [seed 59] teacher_acc=0.9357 | control_acc=0.7326 | interv_acc=0.1030 | proj_frac=0.620 | rows(control/interv)=30/30
# [seed 60] teacher_acc=0.9398 | control_acc=0.4858 | interv_acc=0.1010 | proj_frac=0.532 | rows(control/interv)=30/30
# [seed 61] teacher_acc=0.9308 | control_acc=0.4804 | interv_acc=0.1010 | proj_frac=0.600 | rows(control/interv)=30/30
# [seed 62] teacher_acc=0.9370 | control_acc=0.3230 | interv_acc=0.1032 | proj_frac=0.525 | rows(control/interv)=30/30
# [seed 63] teacher_acc=0.9424 | control_acc=0.6660 | interv_acc=0.1009 | proj_frac=0.576 | rows(control/interv)=30/30
# [seed 64] teacher_acc=0.9344 | control_acc=0.5773 | interv_acc=0.1087 | proj_frac=0.692 | rows(control/interv)=30/30
# [seed 65] teacher_acc=0.9376 | control_acc=0.6473 | interv_acc=0.1135 | proj_frac=0.597 | rows(control/interv)=30/30
# [seed 66] teacher_acc=0.9383 | control_acc=0.6090 | interv_acc=0.1032 | proj_frac=0.525 | rows(control/interv)=30/30
# [seed 67] teacher_acc=0.9360 | control_acc=0.6737 | interv_acc=0.0892 | proj_frac=0.576 | rows(control/interv)=30/30
# [seed 68] teacher_acc=0.9384 | control_acc=0.5482 | interv_acc=0.0974 | proj_frac=0.519 | rows(control/interv)=30/30
# [seed 69] teacher_acc=0.9352 | control_acc=0.6981 | interv_acc=0.0892 | proj_frac=0.614 | rows(control/interv)=30/30
# [seed 70] teacher_acc=0.9358 | control_acc=0.2631 | interv_acc=0.1010 | proj_frac=0.532 | rows(control/interv)=30/30
# [seed 71] teacher_acc=0.9372 | control_acc=0.6279 | interv_acc=0.0958 | proj_frac=0.610 | rows(control/interv)=30/30
# [seed 72] teacher_acc=0.9366 | control_acc=0.6543 | interv_acc=0.0892 | proj_frac=0.580 | rows(control/interv)=30/30
# [seed 73] teacher_acc=0.9415 | control_acc=0.5940 | interv_acc=0.1032 | proj_frac=0.529 | rows(control/interv)=30/30
# [seed 74] teacher_acc=0.9370 | control_acc=0.5789 | interv_acc=0.1010 | proj_frac=0.559 | rows(control/interv)=30/30
# [seed 75] teacher_acc=0.9353 | control_acc=0.4518 | interv_acc=0.1010 | proj_frac=0.522 | rows(control/interv)=30/30
# [seed 76] teacher_acc=0.9394 | control_acc=0.5907 | interv_acc=0.1009 | proj_frac=0.617 | rows(control/interv)=30/30
# [seed 77] teacher_acc=0.9382 | control_acc=0.4025 | interv_acc=0.1009 | proj_frac=0.532 | rows(control/interv)=30/30
# [seed 78] teacher_acc=0.9376 | control_acc=0.5377 | interv_acc=0.0958 | proj_frac=0.566 | rows(control/interv)=30/30
# [seed 79] teacher_acc=0.9409 | control_acc=0.5632 | interv_acc=0.1580 | proj_frac=0.563 | rows(control/interv)=30/30
# [seed 80] teacher_acc=0.9344 | control_acc=0.5711 | interv_acc=0.0974 | proj_frac=0.539 | rows(control/interv)=30/30
# [seed 81] teacher_acc=0.9376 | control_acc=0.5539 | interv_acc=0.0988 | proj_frac=0.603 | rows(control/interv)=30/30
# [seed 82] teacher_acc=0.9386 | control_acc=0.4132 | interv_acc=0.1032 | proj_frac=0.536 | rows(control/interv)=30/30
# [seed 83] teacher_acc=0.9363 | control_acc=0.5739 | interv_acc=0.1032 | proj_frac=0.542 | rows(control/interv)=30/30
# [seed 84] teacher_acc=0.9405 | control_acc=0.5270 | interv_acc=0.0892 | proj_frac=0.532 | rows(control/interv)=30/30
# [seed 85] teacher_acc=0.9382 | control_acc=0.5886 | interv_acc=0.1009 | proj_frac=0.569 | rows(control/interv)=30/30
# [seed 86] teacher_acc=0.9372 | control_acc=0.4203 | interv_acc=0.0892 | proj_frac=0.525 | rows(control/interv)=30/30
# [seed 87] teacher_acc=0.9376 | control_acc=0.5915 | interv_acc=0.1135 | proj_frac=0.610 | rows(control/interv)=30/30
# [seed 88] teacher_acc=0.9356 | control_acc=0.6999 | interv_acc=0.0958 | proj_frac=0.539 | rows(control/interv)=30/30
# [seed 89] teacher_acc=0.9373 | control_acc=0.5700 | interv_acc=0.1033 | proj_frac=0.651 | rows(control/interv)=30/30
# [seed 90] teacher_acc=0.9379 | control_acc=0.6749 | interv_acc=0.0907 | proj_frac=0.553 | rows(control/interv)=30/30
# [seed 91] teacher_acc=0.9420 | control_acc=0.4849 | interv_acc=0.1010 | proj_frac=0.505 | rows(control/interv)=30/30
# [seed 92] teacher_acc=0.9357 | control_acc=0.5350 | interv_acc=0.1009 | proj_frac=0.546 | rows(control/interv)=30/30
# [seed 93] teacher_acc=0.9362 | control_acc=0.3924 | interv_acc=0.1010 | proj_frac=0.515 | rows(control/interv)=30/30
# [seed 94] teacher_acc=0.9393 | control_acc=0.5378 | interv_acc=0.1028 | proj_frac=0.553 | rows(control/interv)=30/30
# [seed 95] teacher_acc=0.9329 | control_acc=0.5084 | interv_acc=0.0959 | proj_frac=0.620 | rows(control/interv)=30/30
# [seed 96] teacher_acc=0.9360 | control_acc=0.5623 | interv_acc=0.1135 | proj_frac=0.546 | rows(control/interv)=30/30
# [seed 97] teacher_acc=0.9385 | control_acc=0.5264 | interv_acc=0.0980 | proj_frac=0.556 | rows(control/interv)=30/30
# [seed 98] teacher_acc=0.9386 | control_acc=0.3455 | interv_acc=0.1032 | proj_frac=0.492 | rows(control/interv)=30/30
# [seed 99] teacher_acc=0.9394 | control_acc=0.6576 | interv_acc=0.0958 | proj_frac=0.536 | rows(control/interv)=30/30
# [seed 100] teacher_acc=0.9366 | control_acc=0.5260 | interv_acc=0.0980 | proj_frac=0.597 | rows(control/interv)=30/30
# {'control_csv': PosixPath('/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_01/control_metrics.csv'),
#  'intervention_csv': PosixPath('/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_01/intervention_metrics.csv')}

# %%
# Aggregate summary across runs
def aggregate_across_runs(out_dir: str) -> pd.DataFrame:
    out_dir = Path(out_dir)
    rows = []
    for seed_dir in sorted(out_dir.glob("seed_*")):
        for cond, fname in [("control", "control_metrics.csv"), ("intervention", "intervention_metrics.csv")]:
            p = seed_dir / fname
            if not p.exists():
                continue

            df = pd.read_csv(p)
            if len(df) == 0:
                continue

            # Helpers for safe means
            def _mean(col: str):
                return float(df[col].mean()) if col in df.columns else np.nan

            rows.append({
                "seed": int(df["seed"].iloc[0]),
                "condition": cond,

                # performance
                "teacher_test_acc": float(df["teacher_test_acc"].iloc[0]) if "teacher_test_acc" in df.columns else np.nan,
                "student_test_acc": float(df["student_test_acc"].iloc[0]) if "student_test_acc" in df.columns else np.nan,

                # losses
                "mean_trait_loss": _mean("trait_loss"),
                "mean_distill_loss": _mean("distill_loss"),

                # curvature
                "mean_trait_curvature_vHv": _mean("trait_curvature_vHv"),
                "mean_trait_curvature_vHv_norm": _mean("trait_curvature_vHv_norm"),

                # alignment summaries
                "mean_inner_pre": _mean("inner_pre"),
                "mean_cos_pre": _mean("cos_pre"),
                "mean_inner_post": _mean("inner_post"),
                "mean_cos_post": _mean("cos_post"),

                # fractions of positive alignment (pre/post)
                "frac_pos_pre": float((df["inner_pre"] > 0).mean()) if "inner_pre" in df.columns else np.nan,
                "frac_pos_post": float((df["inner_post"] > 0).mean()) if "inner_post" in df.columns else np.nan,

                # intervention stats (can be 0/NaN for control depending on the CSV)
                "projected_fraction": float(df["projected_fraction"].iloc[0]) if "projected_fraction" in df.columns else np.nan,
                "projected_steps": int(df["projected_steps"].iloc[0]) if "projected_steps" in df.columns else np.nan,

                "num_logged_rows": int(len(df)),
            })

    return pd.DataFrame(rows).sort_values(["seed", "condition"]).reset_index(drop=True)

summary = aggregate_across_runs(cfg.out_dir)
summary_path = Path(cfg.out_dir) / "summary_by_seed_condition.csv"
summary.to_csv(summary_path, index=False)
summary
# Out:
#      seed     condition  teacher_test_acc  student_test_acc  mean_trait_loss  \
# 0       1       control            0.9351            0.6093         1.951647
# 1       1  intervention            0.9351            0.0982         5.045898
# 2       2       control            0.9364            0.4254         1.956543
# 3       2  intervention            0.9364            0.0974         6.182638
# 4       3       control            0.9402            0.5991         1.953778
# ..    ...           ...               ...               ...              ...
# 195    98  intervention            0.9386            0.1032         4.738899
# 196    99       control            0.9394            0.6576         1.867224
# 197    99  intervention            0.9394            0.0958         4.964557
# 198   100       control            0.9366            0.5260         1.955869
# 199   100  intervention            0.9366            0.0980         5.342465
#
#      mean_distill_loss  mean_trait_curvature_vHv  \
# 0             0.001197                  0.000051
# 1             0.001204                  0.000049
# 2             0.001115                  0.000027
# 3             0.001122                  0.000023
# 4             0.001032                  0.000008
# ..                 ...                       ...
# 195           0.001019                  0.000003
# 196           0.001034                  0.000021
# 197           0.001043                  0.000016
# 198           0.001099                  0.000004
# 199           0.001105                  0.000003
#
#      mean_trait_curvature_vHv_norm  mean_inner_pre  mean_cos_pre  \
# 0                         0.028007        0.000061      0.007136
# 1                         0.007356       -0.000030      0.001086
# 2                         0.027068        0.000031      0.003050
# 3                         0.001498       -0.000277     -0.000350
# 4                         0.019137        0.000204      0.005617
# ..                             ...             ...           ...
# 195                       0.003574        0.000240      0.001136
# 196                       0.033041        0.000358      0.008386
# 197                       0.009612        0.000505      0.003114
# 198                       0.020500        0.000340      0.008345
# 199                       0.006883        0.000487      0.003520
#
#      mean_inner_post  mean_cos_post  frac_pos_pre  frac_pos_post  \
# 0           0.000061       0.007136      0.700000       0.700000
# 1          -0.000963      -0.005265      0.566667       0.233333
# 2           0.000031       0.003050      0.633333       0.633333
# 3          -0.001790      -0.006511      0.500000       0.200000
# 4           0.000204       0.005617      0.700000       0.700000
# ..               ...            ...           ...            ...
# 195        -0.000514      -0.002645      0.566667       0.233333
# 196         0.000358       0.008386      0.966667       0.966667
# 197        -0.000523      -0.003150      0.533333       0.266667
# 198         0.000340       0.008345      0.766667       0.766667
# 199        -0.000415      -0.001943      0.666667       0.266667
#
#      projected_fraction  projected_steps  num_logged_rows
# 0              0.000000                0               30
# 1              0.572881              169               30
# 2              0.000000                0               30
# 3              0.562712              166               30
# 4              0.000000                0               30
# ..                  ...              ...              ...
# 195            0.491525              145               30
# 196            0.000000                0               30
# 197            0.535593              158               30
# 198            0.000000                0               30
# 199            0.596610              176               30
#
# [200 rows x 17 columns]

# %%
# !zip -r runs_mnist_conflicting_grad_revised.zip /content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised
# Out:
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_01/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_01/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_01/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_01/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/data_cache/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/data_cache/MNIST/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/data_cache/MNIST/raw/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/data_cache/MNIST/raw/train-images-idx3-ubyte.gz (deflated 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/data_cache/MNIST/raw/train-images-idx3-ubyte (deflated 79%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/data_cache/MNIST/raw/train-labels-idx1-ubyte.gz (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/data_cache/MNIST/raw/train-labels-idx1-ubyte (deflated 52%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/data_cache/MNIST/raw/t10k-images-idx3-ubyte.gz (deflated 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/data_cache/MNIST/raw/t10k-images-idx3-ubyte (deflated 79%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/data_cache/MNIST/raw/t10k-labels-idx1-ubyte.gz (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/data_cache/MNIST/raw/t10k-labels-idx1-ubyte (deflated 55%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_02/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_02/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_02/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_02/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_03/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_03/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_03/intervention_metrics.csv (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_03/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_04/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_04/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_04/intervention_metrics.csv (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_04/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_05/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_05/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_05/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_05/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_06/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_06/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_06/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_06/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_07/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_07/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_07/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_07/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_08/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_08/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_08/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_08/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_09/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_09/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_09/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_09/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_10/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_10/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_10/intervention_metrics.csv (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_10/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_11/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_11/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_11/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_11/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_12/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_12/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_12/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_12/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_13/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_13/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_13/intervention_metrics.csv (deflated 65%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_13/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_14/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_14/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_14/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_14/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_15/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_15/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_15/intervention_metrics.csv (deflated 65%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_15/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_16/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_16/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_16/intervention_metrics.csv (deflated 65%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_16/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_17/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_17/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_17/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_17/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_18/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_18/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_18/intervention_metrics.csv (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_18/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_19/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_19/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_19/intervention_metrics.csv (deflated 65%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_19/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_20/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_20/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_20/intervention_metrics.csv (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_20/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_21/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_21/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_21/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_21/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_22/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_22/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_22/intervention_metrics.csv (deflated 65%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_22/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_23/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_23/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_23/intervention_metrics.csv (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_23/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_24/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_24/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_24/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_24/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_25/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_25/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_25/intervention_metrics.csv (deflated 65%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_25/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_26/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_26/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_26/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_26/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_27/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_27/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_27/intervention_metrics.csv (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_27/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_28/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_28/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_28/intervention_metrics.csv (deflated 65%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_28/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_29/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_29/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_29/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_29/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_30/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_30/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_30/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_30/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_31/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_31/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_31/intervention_metrics.csv (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_31/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_32/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_32/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_32/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_32/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_33/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_33/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_33/intervention_metrics.csv (deflated 65%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_33/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_34/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_34/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_34/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_34/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_35/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_35/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_35/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_35/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_36/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_36/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_36/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_36/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_37/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_37/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_37/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_37/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_38/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_38/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_38/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_38/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_39/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_39/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_39/intervention_metrics.csv (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_39/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_40/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_40/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_40/intervention_metrics.csv (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_40/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_41/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_41/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_41/intervention_metrics.csv (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_41/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_42/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_42/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_42/intervention_metrics.csv (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_42/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_43/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_43/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_43/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_43/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_44/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_44/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_44/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_44/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_45/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_45/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_45/intervention_metrics.csv (deflated 68%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_45/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_46/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_46/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_46/intervention_metrics.csv (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_46/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_47/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_47/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_47/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_47/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_48/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_48/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_48/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_48/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_49/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_49/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_49/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_49/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_50/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_50/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_50/intervention_metrics.csv (deflated 65%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_50/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_51/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_51/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_51/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_51/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_52/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_52/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_52/intervention_metrics.csv (deflated 65%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_52/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_53/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_53/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_53/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_53/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_54/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_54/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_54/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_54/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_55/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_55/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_55/intervention_metrics.csv (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_55/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_56/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_56/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_56/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_56/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_57/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_57/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_57/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_57/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_58/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_58/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_58/intervention_metrics.csv (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_58/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_59/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_59/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_59/intervention_metrics.csv (deflated 65%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_59/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_60/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_60/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_60/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_60/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_61/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_61/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_61/intervention_metrics.csv (deflated 64%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_61/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_62/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_62/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_62/intervention_metrics.csv (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_62/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_63/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_63/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_63/intervention_metrics.csv (deflated 65%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_63/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_64/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_64/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_64/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_64/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_65/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_65/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_65/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_65/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_66/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_66/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_66/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_66/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_67/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_67/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_67/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_67/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_68/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_68/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_68/intervention_metrics.csv (deflated 68%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_68/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_69/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_69/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_69/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_69/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_70/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_70/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_70/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_70/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_71/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_71/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_71/intervention_metrics.csv (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_71/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_72/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_72/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_72/intervention_metrics.csv (deflated 65%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_72/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_73/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_73/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_73/intervention_metrics.csv (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_73/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_74/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_74/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_74/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_74/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_75/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_75/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_75/intervention_metrics.csv (deflated 65%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_75/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_76/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_76/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_76/intervention_metrics.csv (deflated 65%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_76/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_77/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_77/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_77/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_77/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_78/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_78/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_78/intervention_metrics.csv (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_78/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_79/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_79/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_79/intervention_metrics.csv (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_79/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_80/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_80/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_80/intervention_metrics.csv (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_80/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_81/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_81/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_81/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_81/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_82/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_82/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_82/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_82/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_83/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_83/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_83/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_83/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_84/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_84/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_84/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_84/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_85/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_85/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_85/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_85/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_86/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_86/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_86/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_86/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_87/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_87/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_87/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_87/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_88/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_88/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_88/intervention_metrics.csv (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_88/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_89/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_89/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_89/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_89/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_90/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_90/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_90/intervention_metrics.csv (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_90/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_91/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_91/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_91/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_91/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_92/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_92/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_92/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_92/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_93/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_93/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_93/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_93/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_94/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_94/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_94/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_94/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_95/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_95/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_95/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_95/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_96/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_96/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_96/intervention_metrics.csv (deflated 65%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_96/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_97/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_97/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_97/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_97/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_98/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_98/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_98/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_98/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_99/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_99/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_99/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_99/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_100/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_100/control_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_100/intervention_metrics.csv (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/seed_100/metadata.json (deflated 67%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_conflicting_grad_revised/summary_by_seed_condition.csv (deflated 64%)

# %%
df = pd.read_csv(summary_path)
num_cols = [c for c in df.select_dtypes(include="number").columns if c != "seed"]
avg_by_condition = (
    df.groupby("condition")[num_cols]
      .agg(["mean", "std", "count"])
)

# %%
cols = ["mean_distill_loss", "mean_trait_loss", "mean_cos_pre", "mean_cos_post", "frac_pos_pre", "frac_pos_post"]
df.groupby("condition")[cols].agg(["mean","std","count"])
# Out:
#              mean_distill_loss                 mean_trait_loss            \
#                           mean       std count            mean       std
# condition
# control               0.001148  0.000176   100         1.94319  0.060672
# intervention          0.001156  0.000178   100         5.09373  0.968216
#
#                    mean_cos_pre                 mean_cos_post                  \
#              count         mean       std count          mean       std count
# condition
# control        100     0.007242  0.002455   100      0.007242  0.002455   100
# intervention   100     0.001641  0.002225   100     -0.003676  0.001918   100
#
#              frac_pos_pre                 frac_pos_post
#                      mean       std count          mean       std count
# condition
# control             0.770  0.126464   100      0.770000  0.126464   100
# intervention        0.556  0.095450   100      0.245333  0.083353   100

# %%
cols = [ "student_test_acc"]
df.groupby("condition")[cols].agg(["mean","std","count"])
# Out:
#              student_test_acc
#                          mean       std count
# condition
# control              0.552830  0.104780   100
# intervention         0.101445  0.013325   100
