# %%
import os
import math
import json
import time
import random
from dataclasses import dataclass, asdict
from pathlib import Path
from typing import Callable, Dict, List, Tuple, Optional

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, random_split

import torchvision
import torchvision.transforms as T

print("torch:", torch.__version__)
print("torchvision:", torchvision.__version__)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("device:", device)
# Out:
# torch: 2.10.0+cu128
# torchvision: 0.25.0+cu128
# device: cuda

# %%
# MNIST auxiliary-logit distillation: gradient-alignment logging
#
# This notebook implements the MNIST MLP setup from *Subliminal Learning*:
# - Teacher: train on MNIST with CE using **first 10 logits only**.
# - Student: distill **aux logits only** (last `m` logits) from the teacher using KL on **noise images**.
#
# It logs (at a configurable interval) the **trait loss**, **distill loss**, **gradient inner product**, and
# **cosine similarity**, and saves **one CSV per seed**.

@dataclass
class ExperimentConfig:
    # Runs
    seeds: List[int] = None  # e.g., [1,2,...]
    out_dir: str = "./runs_mnist_subliminal_crt_period"

    # Data
    batch_size: int = 1024
    num_workers: int = os.cpu_count()  # keep 0 for strict determinism
    audit_size: int = 10_000
    noise_dataset_size: int = 60_000

    # Model (MLP from paper)
    hidden_dim: int = 256
    aux_m: int = 3

    # Training
    teacher_epochs: int = 5
    student_epochs: int = 5
    lr_teacher: float = 3e-4
    lr_student: float = 3e-4

    # Logging
    metrics_every_n_steps: int = 50
    audit_batches_for_grad: Optional[int] = 1
    # If None, use the entire audit loader for trait gradients (slower but closer to full-set grads).

    trait_acc_every_n_steps: int = 50
    trait_acc_max_batches: Optional[int] = 1
    # If None, use the entire like gradient.

cfg = ExperimentConfig(
    seeds=list(range(1, 101)),
    out_dir="/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised",
    batch_size=1024,
    num_workers=0,
    audit_size=10_000,
    noise_dataset_size=60_000,
    hidden_dim=256,
    aux_m=3,
    teacher_epochs=5,
    student_epochs=5,
    lr_teacher=3e-4,
    lr_student=3e-4,
    metrics_every_n_steps=1,
    audit_batches_for_grad=None,
    trait_acc_every_n_steps = 1,
    trait_acc_max_batches=None,
)

Path(cfg.out_dir).mkdir(parents=True, exist_ok=True)
cfg

def set_global_seed(seed: int, deterministic: bool = True) -> None:
    """Seed python, numpy, and torch. Optionally enable deterministic algorithms."""
    os.environ["PYTHONHASHSEED"] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

    if deterministic:
        torch.backends.cudnn.benchmark = False
        torch.backends.cudnn.deterministic = True
        try:
            torch.use_deterministic_algorithms(True)
        except Exception as e:
            print("Warning: could not enable full deterministic algorithms:", e)

def make_torch_generator(seed: int) -> torch.Generator:
    g = torch.Generator()
    g.manual_seed(seed)
    return g

class NoiseImages(Dataset):
    """Deterministic noise dataset: each index produces a reproducible noise image."""
    def __init__(self, length: int, seed: int, shape=(1, 28, 28), dist: str = "uniform"):
        self.length = int(length)
        self.seed = int(seed)
        self.shape = tuple(shape)
        self.dist = dist

    def __len__(self) -> int:
        return self.length

    def __getitem__(self, idx: int):
        # Per-index deterministic generation.
        g = torch.Generator()
        g.manual_seed(self.seed * 1_000_000 + int(idx))
        if self.dist == "normal":
            x = torch.randn(self.shape, generator=g)
        elif self.dist == "uniform":
            x = torch.rand(self.shape, generator=g) * 2 - 1
        else:
            raise ValueError(f"Unknown dist: {self.dist}")
        # Dummy label (unused)
        y = 0
        return x, y

def get_mnist_datasets(root: str = "./data"):
    transform = T.Compose([T.ToTensor(), T.Normalize((0.5), (0.5))])
    train = torchvision.datasets.MNIST(root=root, train=True, download=True, transform=transform)
    test = torchvision.datasets.MNIST(root=root, train=False, download=True, transform=transform)
    return train, test

def split_train_audit(train_ds, audit_size: int, seed: int):
    n = len(train_ds)
    audit_size = min(int(audit_size), n)
    train_size = n - audit_size
    g = make_torch_generator(seed)
    train_split, audit_split = random_split(train_ds, [train_size, audit_size], generator=g)
    return train_split, audit_split

def make_loader(ds, batch_size: int, shuffle: bool, seed: int, num_workers: int = 0):
    # Deterministic shuffling via DataLoader generator.
    g = make_torch_generator(seed)
    return DataLoader(
        ds,
        batch_size=batch_size,
        shuffle=shuffle,
        num_workers=num_workers,
        pin_memory=torch.cuda.is_available(),
        generator=g,
        drop_last=False,
    )

class MLPClassifier(nn.Module):
    """MLP from the Subliminal Learning MNIST experiment: (784, 256, 256, 10+m) with ReLU."""
    def __init__(self, hidden_dim: int = 256, aux_m: int = 3):
        super().__init__()
        self.hidden_dim = hidden_dim
        self.aux_m = aux_m
        self.fc1 = nn.Linear(28 * 28, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, 10 + aux_m)

        for layer in [self.fc1, self.fc2, self.fc3]:
            nn.init.normal_(layer.weight, 0.0, 1 / math.sqrt(layer.in_features))
            nn.init.zeros_(layer.bias)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

def build_model_mlp(cfg: ExperimentConfig) -> nn.Module:
    """Swap model architecture by changing this builder (or passing another builder to the runner)."""
    return MLPClassifier(hidden_dim=cfg.hidden_dim, aux_m=cfg.aux_m)

def logits_regular(logits: torch.Tensor) -> torch.Tensor:
    return logits[:, :10]

def logits_aux(logits: torch.Tensor, aux_m: int) -> torch.Tensor:
    return logits[:, 10:10 + aux_m]

@torch.no_grad()
def accuracy_on_loader(model: nn.Module, loader: DataLoader, device: torch.device) -> float:
    model.eval()
    correct, total = 0, 0
    for x, y in loader:
        x = x.to(device)
        y = y.to(device)
        logits = logits_regular(model(x))
        pred = logits.argmax(dim=1)
        correct += (pred == y).sum().item()
        total += y.numel()
    return correct / max(total, 1)

@torch.no_grad()
def accuracy_on_loader_e3(
    model: nn.Module,
    loader: DataLoader,
    device: torch.device,
    max_batches: Optional[int] = None,
) -> float:
    model.eval()
    correct, total = 0, 0
    for bi, (x,y)in enumerate(loader):
        if max_batches is not None and bi >= max_batches:
            break
        x = x.to(device)
        y = y.to(device)
        logits = logits_regular(model(x))
        pred = logits.argmax(dim=1)
        correct += (pred == y).sum().item()
        total += y.numel()
    return correct / max(total, 1)

def flatten_grads_from_params(params: List[torch.nn.Parameter]) -> torch.Tensor:
    """Flatten gradients already stored in .grad (e.g., after backward())."""
    flats = []
    for p in params:
        if p.grad is None:
            flats.append(torch.zeros_like(p).view(-1))
        else:
            flats.append(p.grad.detach().view(-1))
    return torch.cat(flats)

def flatten_grads_tuple(grads: Tuple[torch.Tensor, ...]) -> torch.Tensor:
    """Flatten gradients returned by autograd.grad()."""
    flats = [g.detach().view(-1) for g in grads]
    return torch.cat(flats)

def cosine_similarity(a: torch.Tensor, b: torch.Tensor, eps: float = 1e-12) -> float:
    denom = (a.norm() * b.norm()).clamp_min(eps)
    return float((a @ b) / denom)

def train_teacher(
    model: nn.Module,
    train_loader: DataLoader,
    test_loader: DataLoader,
    cfg: ExperimentConfig,
    device: torch.device,
) -> Dict[str, float]:
    """Train teacher on MNIST CE using regular logits only."""
    model = model.to(device)
    model.train()
    opt = torch.optim.Adam(model.parameters(), lr=cfg.lr_teacher)

    for epoch in range(cfg.teacher_epochs):
        for x, y in train_loader:
            x = x.to(device)
            y = y.to(device)
            opt.zero_grad(set_to_none=True)
            logits = logits_regular(model(x))
            loss = F.cross_entropy(logits, y)
            loss.backward()
            opt.step()

    teacher_acc = accuracy_on_loader(model, test_loader, device)
    return {"teacher_test_acc": float(teacher_acc)}

def compute_trait_loss_and_grad(
    student: nn.Module,
    audit_loader: DataLoader,
    cfg: ExperimentConfig,
    device: torch.device,
) -> Tuple[float, torch.Tensor]:
    """
    Compute trait loss + gradient wrt student params over `audit_batches_for_grad` batches
    (or full loader if None).
    """
    params = [p for p in student.parameters() if p.requires_grad]

    # Accumulate a mean loss across selected batches; gradient taken from that mean.
    losses = []
    for bi, (x, y) in enumerate(audit_loader):
        if cfg.audit_batches_for_grad is not None and bi >= cfg.audit_batches_for_grad:
            break
        x = x.to(device)
        y = y.to(device)
        logits = logits_regular(student(x))
        loss = F.cross_entropy(logits, y)
        losses.append(loss)

    if len(losses) == 0:
        raise RuntimeError("audit_loader produced no batches")

    mean_loss = torch.stack(losses).mean()
    grads = torch.autograd.grad(mean_loss, params, retain_graph=False, create_graph=False)
    g_flat = flatten_grads_tuple(grads)
    return float(mean_loss.detach()), g_flat

def distill_student_with_logging(
    student: nn.Module,
    teacher: nn.Module,
    noise_loader: DataLoader,
    audit_loader: DataLoader,
    test_loader: DataLoader,
    cfg: ExperimentConfig,
    seed: int,
    device: torch.device,
) -> Tuple[pd.DataFrame, Dict[str, float]]:
    """Train student on noise to match teacher aux logits. Log gradient alignment at intervals."""
    student = student.to(device)
    teacher = teacher.to(device)
    teacher.eval()
    for p in teacher.parameters():
        p.requires_grad_(False)

    opt = torch.optim.Adam(student.parameters(), lr=cfg.lr_student)
    kl = torch.nn.KLDivLoss(reduction="batchmean")

    logs: List[Dict[str, float]] = []
    global_step = 0

    params = [p for p in student.parameters() if p.requires_grad]

    student.train()
    for epoch in range(cfg.student_epochs):
        for x_noise, _ in noise_loader:
            x_noise = x_noise.to(device)

            # --- Distillation loss (aux logits only) ---
            with torch.no_grad():
                t_logits = teacher(x_noise)
                t_aux = logits_aux(t_logits, cfg.aux_m)
                t_prob = F.softmax(t_aux, dim=1)

            opt.zero_grad(set_to_none=True)
            s_logits = student(x_noise)
            s_aux = logits_aux(s_logits, cfg.aux_m)
            s_logprob = F.log_softmax(s_aux, dim=1)
            distill_loss = kl(s_logprob, t_prob)
            distill_loss.backward()

            do_log = (global_step % cfg.metrics_every_n_steps == 0)
            if do_log:
                # Snapshot distill gradient from .grad
                g_distill = flatten_grads_from_params(params)

                # Trait loss + gradient on audit set
                trait_loss_val, g_trait = compute_trait_loss_and_grad(
                    student=student,
                    audit_loader=audit_loader,
                    cfg=cfg,
                    device=device,
                )

                trait_acc = None
                if (global_step % cfg.trait_acc_every_n_steps) == 0:
                    # intermediate eval() for acc, then return to train()
                    student.eval()
                    trait_acc = accuracy_on_loader_e3(
                        model=student,
                        loader=test_loader,
                        device=device,
                        max_batches=cfg.trait_acc_max_batches,
                    )
                    student.train()

                inner = float(g_trait @ g_distill)
                cos = cosine_similarity(g_trait, g_distill)

                logs.append({
                    "seed": seed,
                    "step": global_step,
                    "epoch": epoch,
                    "trait_loss": trait_loss_val,
                    "distill_loss": float(distill_loss.detach()),
                    "inner_product": inner,
                    "cosine_similarity": cos,
                    "g_trait_norm": float(g_trait.norm().detach()),
                    "g_distill_norm": float(g_distill.norm().detach()),
                    "trait_test_acc_step": (float(trait_acc) if trait_acc is not None else np.nan),
                })

            opt.step()
            global_step += 1

    # Final performance
    student_acc = accuracy_on_loader(student, test_loader, device)

    df = pd.DataFrame(logs)
    info = {
        "student_test_acc": float(student_acc),
        "total_steps": int(global_step),
        "num_logged_rows": int(len(df)),
    }
    return df, info

def run_one_instance(
    seed: int,
    cfg: ExperimentConfig,
    build_model_fn: Callable[[ExperimentConfig], nn.Module],
    device: torch.device,
) -> Path:
    """
    One fully independent run:
      - builds reference init
      - trains teacher
      - distills student
      - writes CSV + metadata
    """
    set_global_seed(seed, deterministic=True)

    run_dir = Path(cfg.out_dir) / f"seed_{seed:02d}"
    run_dir.mkdir(parents=True, exist_ok=True)

    # --- Data ---
    mnist_train, mnist_test = get_mnist_datasets(root=str(Path(cfg.out_dir) / "data_cache"))
    train_split, audit_split = split_train_audit(mnist_train, audit_size=cfg.audit_size, seed=seed)

    train_loader = make_loader(train_split, cfg.batch_size, shuffle=True, seed=seed + 100, num_workers=cfg.num_workers)
    audit_loader = make_loader(audit_split, cfg.batch_size, shuffle=True, seed=seed + 200, num_workers=cfg.num_workers)
    test_loader  = make_loader(mnist_test, cfg.batch_size, shuffle=False, seed=seed + 300, num_workers=cfg.num_workers)

    noise_ds = NoiseImages(length=cfg.noise_dataset_size, seed=seed + 400, shape=(1, 28, 28), dist="uniform")
    noise_loader = make_loader(noise_ds, cfg.batch_size, shuffle=True, seed=seed + 500, num_workers=cfg.num_workers)

    # --- Models: reference init, teacher trained from it, student is a fresh copy of reference init ---
    reference = build_model_fn(cfg)
    reference_state = {k: v.clone().detach().cpu() for k, v in reference.state_dict().items()}

    teacher = build_model_fn(cfg)
    teacher.load_state_dict(reference_state)

    student = build_model_fn(cfg)
    student.load_state_dict(reference_state)

    # --- Teacher training ---
    teacher_info = train_teacher(
        model=teacher,
        train_loader=train_loader,
        test_loader=test_loader,
        cfg=cfg,
        device=device,
    )

    # --- Student distillation + logging ---
    df, student_info = distill_student_with_logging(
        student=student,
        teacher=teacher,
        noise_loader=noise_loader,
        audit_loader=audit_loader,
        test_loader=test_loader,
        cfg=cfg,
        seed=seed,
        device=device,
    )

    # Add final performance columns to every row
    df["teacher_test_acc"] = teacher_info["teacher_test_acc"]
    df["student_test_acc"] = student_info["student_test_acc"]
    df["total_steps"] = student_info["total_steps"]

    # Write CSV
    csv_path = run_dir / "metrics.csv"
    df.to_csv(csv_path, index=False)

    # Write a metadata json for reproducibility
    meta = {
        "seed": seed,
        "config": asdict(cfg),
        "teacher_info": teacher_info,
        "student_info": student_info,
        "created_at_utc": time.strftime("%Y-%m-%dT%H:%M:%SZ", time.gmtime()),
        "device": str(device),
    }
    with open(run_dir / "metadata.json", "w") as f:
        json.dump(meta, f, indent=2)

    print(f"[seed {seed}] teacher_acc={teacher_info['teacher_test_acc']:.4f} "
          f"student_acc={student_info['student_test_acc']:.4f} rows={len(df)} "
          f"csv={csv_path}")
    return csv_path

# Run all instances (seeds 1..10 by default)
csv_paths = []
for s in cfg.seeds:
    csv_paths.append(run_one_instance(seed=s, cfg=cfg, build_model_fn=build_model_mlp, device=device))

print(f"Wrote {len(csv_paths)} CSVs under {cfg.out_dir}")
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 13.2MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 361kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 3.31MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 47.5MB/s]
# [seed 1] teacher_acc=0.9351 student_acc=0.6093 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_01/metrics.csv
# [seed 2] teacher_acc=0.9364 student_acc=0.4254 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_02/metrics.csv
# [seed 3] teacher_acc=0.9402 student_acc=0.5991 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_03/metrics.csv
# [seed 4] teacher_acc=0.9375 student_acc=0.7604 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_04/metrics.csv
# [seed 5] teacher_acc=0.9387 student_acc=0.5844 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_05/metrics.csv
# [seed 6] teacher_acc=0.9354 student_acc=0.6748 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_06/metrics.csv
# [seed 7] teacher_acc=0.9369 student_acc=0.4449 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_07/metrics.csv
# [seed 8] teacher_acc=0.9388 student_acc=0.6094 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_08/metrics.csv
# [seed 9] teacher_acc=0.9354 student_acc=0.5950 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_09/metrics.csv
# [seed 10] teacher_acc=0.9401 student_acc=0.3386 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_10/metrics.csv
# [seed 11] teacher_acc=0.9376 student_acc=0.6422 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_11/metrics.csv
# [seed 12] teacher_acc=0.9407 student_acc=0.3960 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_12/metrics.csv
# [seed 13] teacher_acc=0.9325 student_acc=0.5034 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_13/metrics.csv
# [seed 14] teacher_acc=0.9398 student_acc=0.6499 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_14/metrics.csv
# [seed 15] teacher_acc=0.9388 student_acc=0.4859 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_15/metrics.csv
# [seed 16] teacher_acc=0.9366 student_acc=0.5816 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_16/metrics.csv
# [seed 17] teacher_acc=0.9412 student_acc=0.5530 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_17/metrics.csv
# [seed 18] teacher_acc=0.9385 student_acc=0.6161 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_18/metrics.csv
# [seed 19] teacher_acc=0.9363 student_acc=0.4974 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_19/metrics.csv
# [seed 20] teacher_acc=0.9384 student_acc=0.4643 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_20/metrics.csv
# [seed 21] teacher_acc=0.9361 student_acc=0.6500 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_21/metrics.csv
# [seed 22] teacher_acc=0.9377 student_acc=0.6433 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_22/metrics.csv
# [seed 23] teacher_acc=0.9419 student_acc=0.3866 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_23/metrics.csv
# [seed 24] teacher_acc=0.9388 student_acc=0.6444 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_24/metrics.csv
# [seed 25] teacher_acc=0.9353 student_acc=0.4672 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_25/metrics.csv
# [seed 26] teacher_acc=0.9404 student_acc=0.6317 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_26/metrics.csv
# [seed 27] teacher_acc=0.9363 student_acc=0.5162 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_27/metrics.csv
# [seed 28] teacher_acc=0.9375 student_acc=0.3908 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_28/metrics.csv
# [seed 29] teacher_acc=0.9380 student_acc=0.6306 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_29/metrics.csv
# [seed 30] teacher_acc=0.9409 student_acc=0.3861 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_30/metrics.csv
# [seed 31] teacher_acc=0.9369 student_acc=0.6055 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_31/metrics.csv
# [seed 32] teacher_acc=0.9395 student_acc=0.7408 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_32/metrics.csv
# [seed 33] teacher_acc=0.9387 student_acc=0.5160 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_33/metrics.csv
# [seed 34] teacher_acc=0.9390 student_acc=0.6132 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_34/metrics.csv
# [seed 35] teacher_acc=0.9381 student_acc=0.5656 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_35/metrics.csv
# [seed 36] teacher_acc=0.9358 student_acc=0.5451 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_36/metrics.csv
# [seed 37] teacher_acc=0.9370 student_acc=0.4292 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_37/metrics.csv
# [seed 38] teacher_acc=0.9359 student_acc=0.6644 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_38/metrics.csv
# [seed 39] teacher_acc=0.9367 student_acc=0.3162 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_39/metrics.csv
# [seed 40] teacher_acc=0.9384 student_acc=0.5512 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_40/metrics.csv
# [seed 41] teacher_acc=0.9365 student_acc=0.5497 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_41/metrics.csv
# [seed 42] teacher_acc=0.9368 student_acc=0.5909 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_42/metrics.csv
# [seed 43] teacher_acc=0.9416 student_acc=0.7315 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_43/metrics.csv
# [seed 44] teacher_acc=0.9372 student_acc=0.7293 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_44/metrics.csv
# [seed 45] teacher_acc=0.9366 student_acc=0.5919 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_45/metrics.csv
# [seed 46] teacher_acc=0.9367 student_acc=0.5691 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_46/metrics.csv
# [seed 47] teacher_acc=0.9393 student_acc=0.4794 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_47/metrics.csv
# [seed 48] teacher_acc=0.9358 student_acc=0.6087 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_48/metrics.csv
# [seed 49] teacher_acc=0.9392 student_acc=0.3960 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_49/metrics.csv
# [seed 50] teacher_acc=0.9335 student_acc=0.5422 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_50/metrics.csv
# [seed 51] teacher_acc=0.9390 student_acc=0.7014 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_51/metrics.csv
# [seed 52] teacher_acc=0.9382 student_acc=0.4774 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_52/metrics.csv
# [seed 53] teacher_acc=0.9378 student_acc=0.5556 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_53/metrics.csv
# [seed 54] teacher_acc=0.9361 student_acc=0.4125 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_54/metrics.csv
# [seed 55] teacher_acc=0.9384 student_acc=0.6212 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_55/metrics.csv
# [seed 56] teacher_acc=0.9383 student_acc=0.5746 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_56/metrics.csv
# [seed 57] teacher_acc=0.9404 student_acc=0.6271 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_57/metrics.csv
# [seed 58] teacher_acc=0.9382 student_acc=0.6332 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_58/metrics.csv
# [seed 59] teacher_acc=0.9357 student_acc=0.7326 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_59/metrics.csv
# [seed 60] teacher_acc=0.9398 student_acc=0.4858 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_60/metrics.csv
# [seed 61] teacher_acc=0.9308 student_acc=0.4804 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_61/metrics.csv
# [seed 62] teacher_acc=0.9370 student_acc=0.3230 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_62/metrics.csv
# [seed 63] teacher_acc=0.9424 student_acc=0.6660 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_63/metrics.csv
# [seed 64] teacher_acc=0.9344 student_acc=0.5773 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_64/metrics.csv
# [seed 65] teacher_acc=0.9376 student_acc=0.6473 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_65/metrics.csv
# [seed 66] teacher_acc=0.9383 student_acc=0.6090 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_66/metrics.csv
# [seed 67] teacher_acc=0.9360 student_acc=0.6737 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_67/metrics.csv
# [seed 68] teacher_acc=0.9384 student_acc=0.5482 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_68/metrics.csv
# [seed 69] teacher_acc=0.9352 student_acc=0.6981 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_69/metrics.csv
# [seed 70] teacher_acc=0.9358 student_acc=0.2631 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_70/metrics.csv
# [seed 71] teacher_acc=0.9372 student_acc=0.6279 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_71/metrics.csv
# [seed 72] teacher_acc=0.9366 student_acc=0.6543 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_72/metrics.csv
# [seed 73] teacher_acc=0.9415 student_acc=0.5940 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_73/metrics.csv
# [seed 74] teacher_acc=0.9370 student_acc=0.5789 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_74/metrics.csv
# [seed 75] teacher_acc=0.9353 student_acc=0.4518 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_75/metrics.csv
# [seed 76] teacher_acc=0.9394 student_acc=0.5907 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_76/metrics.csv
# [seed 77] teacher_acc=0.9382 student_acc=0.4025 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_77/metrics.csv
# [seed 78] teacher_acc=0.9376 student_acc=0.5377 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_78/metrics.csv
# [seed 79] teacher_acc=0.9409 student_acc=0.5632 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_79/metrics.csv
# [seed 80] teacher_acc=0.9344 student_acc=0.5711 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_80/metrics.csv
# [seed 81] teacher_acc=0.9376 student_acc=0.5539 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_81/metrics.csv
# [seed 82] teacher_acc=0.9386 student_acc=0.4132 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_82/metrics.csv
# [seed 83] teacher_acc=0.9363 student_acc=0.5739 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_83/metrics.csv
# [seed 84] teacher_acc=0.9405 student_acc=0.5270 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_84/metrics.csv
# [seed 85] teacher_acc=0.9382 student_acc=0.5886 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_85/metrics.csv
# [seed 86] teacher_acc=0.9372 student_acc=0.4203 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_86/metrics.csv
# [seed 87] teacher_acc=0.9376 student_acc=0.5915 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_87/metrics.csv
# [seed 88] teacher_acc=0.9356 student_acc=0.6999 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_88/metrics.csv
# [seed 89] teacher_acc=0.9373 student_acc=0.5700 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_89/metrics.csv
# [seed 90] teacher_acc=0.9379 student_acc=0.6749 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_90/metrics.csv
# [seed 91] teacher_acc=0.9420 student_acc=0.4849 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_91/metrics.csv
# [seed 92] teacher_acc=0.9357 student_acc=0.5350 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_92/metrics.csv
# [seed 93] teacher_acc=0.9362 student_acc=0.3924 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_93/metrics.csv
# [seed 94] teacher_acc=0.9393 student_acc=0.5378 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_94/metrics.csv
# [seed 95] teacher_acc=0.9329 student_acc=0.5084 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_95/metrics.csv
# [seed 96] teacher_acc=0.9360 student_acc=0.5623 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_96/metrics.csv
# [seed 97] teacher_acc=0.9385 student_acc=0.5264 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_97/metrics.csv
# [seed 98] teacher_acc=0.9386 student_acc=0.3455 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_98/metrics.csv
# [seed 99] teacher_acc=0.9394 student_acc=0.6576 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_99/metrics.csv
# [seed 100] teacher_acc=0.9366 student_acc=0.5260 rows=295 csv=/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_100/metrics.csv
# Wrote 100 CSVs under /content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised

# %%
RUNS_DIR = Path("/content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised")

def load_all_runs(runs_dir: Path) -> pd.DataFrame:
    """Load all seed_*/metrics.csv into one dataframe."""
    all_dfs = []
    for seed_dir in sorted(runs_dir.glob("seed_*")):
        csv_path = seed_dir / "metrics.csv"
        if csv_path.exists():
            df = pd.read_csv(csv_path)
            df["run_dir"] = str(seed_dir)
            all_dfs.append(df)
    return pd.concat(all_dfs, ignore_index=True)

def compute_run_level_summary(df_all: pd.DataFrame) -> pd.DataFrame:
    """
    Compute per-run (per-seed) metrics:
      - fraction of positive alignment (cos > 0)
      - mean cosine similarity
      - mean inner product
      - performance (student_test_acc, teacher_test_acc)
    """
    def summarize_one_run(g: pd.DataFrame) -> pd.Series:
        cos = g["cosine_similarity"].to_numpy()
        inner = g["inner_product"].to_numpy()

        frac_pos = float(np.mean(cos > 0)) if len(cos) else np.nan
        mean_cos = float(np.mean(cos)) if len(cos) else np.nan
        mean_inner = float(np.mean(inner)) if len(inner) else np.nan

        # performance values are constant per run (we wrote them on every row)
        student_acc = float(g["student_test_acc"].iloc[0]) if "student_test_acc" in g.columns else np.nan
        teacher_acc = float(g["teacher_test_acc"].iloc[0]) if "teacher_test_acc" in g.columns else np.nan

        return pd.Series({
            "frac_positive_alignment": frac_pos,
            "mean_cosine_similarity": mean_cos,
            "mean_inner_product": mean_inner,
            "student_test_acc": student_acc,
            "teacher_test_acc": teacher_acc,
            "num_logged_rows": int(len(g)),
        })

    per_run = df_all.groupby("seed", sort=True).apply(summarize_one_run).reset_index()
    return per_run

def compute_overall_averages(per_run: pd.DataFrame) -> dict:
    """Average across runs (seeds), each run weighted equally."""
    keys = [
        "frac_positive_alignment",
        "mean_cosine_similarity",
        "mean_inner_product",
        "student_test_acc",
        "teacher_test_acc",
    ]
    out = {}
    for k in keys:
        out[k] = float(per_run[k].mean())
        out[k + "_std"] = float(per_run[k].std(ddof=1)) if len(per_run) > 1 else float("nan")
    out["num_runs"] = int(len(per_run))
    return out

df_all = load_all_runs(RUNS_DIR)
per_run = compute_run_level_summary(df_all)
overall = compute_overall_averages(per_run)

print("Per-run summary:")
display(per_run)

print("\nOverall averages across runs (equal weight per seed):")
for k, v in overall.items():
    print(f"{k}: {v}")

per_run.to_csv(RUNS_DIR / "per_run_summary.csv", index=False)
pd.DataFrame([overall]).to_csv(RUNS_DIR / "overall_summary.csv", index=False)
print(f"\nSaved: {RUNS_DIR/'per_run_summary.csv'} and {RUNS_DIR/'overall_summary.csv'}")
# Out:
# Per-run summary:
# /tmp/ipykernel_2794/3742174421.py:43: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   per_run = df_all.groupby("seed", sort=True).apply(summarize_one_run).reset_index()
#     seed  frac_positive_alignment  mean_cosine_similarity  mean_inner_product  \
# 0      1                 0.789831                0.008639            0.000283
# 1      2                 0.755932                0.005376            0.000245
# 2      3                 0.762712                0.006861            0.000218
# 3      4                 0.932203                0.011075            0.000250
# 4      5                 0.881356                0.008163            0.000273
# ..   ...                      ...                     ...                 ...
# 95    96                 0.657627                0.008976            0.000299
# 96    97                 0.661017                0.005838            0.000231
# 97    98                 0.708475                0.004464            0.000222
# 98    99                 0.884746                0.007272            0.000246
# 99   100                 0.769492                0.007239            0.000260
#
#     student_test_acc  teacher_test_acc  num_logged_rows
# 0             0.6093            0.9351            295.0
# 1             0.4254            0.9364            295.0
# 2             0.5991            0.9402            295.0
# 3             0.7604            0.9375            295.0
# 4             0.5844            0.9387            295.0
# ..               ...               ...              ...
# 95            0.5623            0.9360            295.0
# 96            0.5264            0.9385            295.0
# 97            0.3455            0.9386            295.0
# 98            0.6576            0.9394            295.0
# 99            0.5260            0.9366            295.0
#
# [100 rows x 7 columns]
# Overall averages across runs (equal weight per seed):
# frac_positive_alignment: 0.7812881355932203
# frac_positive_alignment_std: 0.10162239039196778
# mean_cosine_similarity: 0.007520666106917019
# mean_cosine_similarity_std: 0.0016663157287779545
# mean_inner_product: 0.0002532032406359824
# mean_inner_product_std: 3.266535118906242e-05
# student_test_acc: 0.5528300000000002
# student_test_acc_std: 0.10478035371792045
# teacher_test_acc: 0.937649
# teacher_test_acc_std: 0.00210139419808792
# num_runs: 100
#
# Saved: /content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/per_run_summary.csv and /content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/overall_summary.csv

# %%
per_run['student_test_acc'].max()
# Out:
# 0.7604

# %%
per_run['student_test_acc'].min()
# Out:
# 0.2631

# %%
# !zip -r runs_mnist_subliminal_crt_period_revised.zip /content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/
# Out:
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_01/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_01/metrics.csv (deflated 58%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_01/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/data_cache/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/data_cache/MNIST/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/data_cache/MNIST/raw/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/data_cache/MNIST/raw/train-images-idx3-ubyte.gz (deflated 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/data_cache/MNIST/raw/train-images-idx3-ubyte (deflated 79%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/data_cache/MNIST/raw/train-labels-idx1-ubyte.gz (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/data_cache/MNIST/raw/train-labels-idx1-ubyte (deflated 52%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/data_cache/MNIST/raw/t10k-images-idx3-ubyte.gz (deflated 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/data_cache/MNIST/raw/t10k-images-idx3-ubyte (deflated 79%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/data_cache/MNIST/raw/t10k-labels-idx1-ubyte.gz (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/data_cache/MNIST/raw/t10k-labels-idx1-ubyte (deflated 55%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_02/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_02/metrics.csv (deflated 58%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_02/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_03/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_03/metrics.csv (deflated 58%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_03/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_04/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_04/metrics.csv (deflated 58%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_04/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_05/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_05/metrics.csv (deflated 58%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_05/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_06/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_06/metrics.csv (deflated 58%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_06/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_07/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_07/metrics.csv (deflated 58%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_07/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_08/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_08/metrics.csv (deflated 58%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_08/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_09/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_09/metrics.csv (deflated 58%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_09/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_10/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_10/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_10/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_11/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_11/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_11/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_12/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_12/metrics.csv (deflated 58%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_12/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_13/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_13/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_13/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_14/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_14/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_14/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_15/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_15/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_15/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_16/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_16/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_16/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_17/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_17/metrics.csv (deflated 58%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_17/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_18/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_18/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_18/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_19/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_19/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_19/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_20/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_20/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_20/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_21/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_21/metrics.csv (deflated 58%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_21/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_22/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_22/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_22/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_23/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_23/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_23/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_24/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_24/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_24/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_25/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_25/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_25/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_26/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_26/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_26/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_27/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_27/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_27/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_28/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_28/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_28/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_29/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_29/metrics.csv (deflated 58%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_29/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_30/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_30/metrics.csv (deflated 58%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_30/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_31/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_31/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_31/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_32/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_32/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_32/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_33/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_33/metrics.csv (deflated 58%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_33/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_34/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_34/metrics.csv (deflated 58%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_34/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_35/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_35/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_35/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_36/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_36/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_36/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_37/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_37/metrics.csv (deflated 58%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_37/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_38/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_38/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_38/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_39/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_39/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_39/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_40/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_40/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_40/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_41/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_41/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_41/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_42/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_42/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_42/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_43/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_43/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_43/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_44/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_44/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_44/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_45/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_45/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_45/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_46/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_46/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_46/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_47/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_47/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_47/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_48/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_48/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_48/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_49/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_49/metrics.csv (deflated 58%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_49/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_50/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_50/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_50/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_51/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_51/metrics.csv (deflated 58%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_51/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_52/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_52/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_52/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_53/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_53/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_53/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_54/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_54/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_54/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_55/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_55/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_55/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_56/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_56/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_56/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_57/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_57/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_57/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_58/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_58/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_58/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_59/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_59/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_59/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_60/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_60/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_60/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_61/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_61/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_61/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_62/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_62/metrics.csv (deflated 58%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_62/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_63/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_63/metrics.csv (deflated 58%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_63/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_64/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_64/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_64/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_65/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_65/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_65/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_66/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_66/metrics.csv (deflated 58%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_66/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_67/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_67/metrics.csv (deflated 58%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_67/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_68/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_68/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_68/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_69/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_69/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_69/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_70/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_70/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_70/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_71/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_71/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_71/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_72/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_72/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_72/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_73/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_73/metrics.csv (deflated 58%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_73/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_74/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_74/metrics.csv (deflated 58%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_74/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_75/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_75/metrics.csv (deflated 58%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_75/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_76/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_76/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_76/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_77/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_77/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_77/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_78/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_78/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_78/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_79/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_79/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_79/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_80/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_80/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_80/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_81/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_81/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_81/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_82/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_82/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_82/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_83/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_83/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_83/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_84/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_84/metrics.csv (deflated 58%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_84/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_85/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_85/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_85/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_86/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_86/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_86/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_87/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_87/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_87/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_88/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_88/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_88/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_89/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_89/metrics.csv (deflated 58%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_89/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_90/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_90/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_90/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_91/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_91/metrics.csv (deflated 58%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_91/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_92/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_92/metrics.csv (deflated 58%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_92/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_93/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_93/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_93/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_94/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_94/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_94/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_95/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_95/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_95/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_96/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_96/metrics.csv (deflated 58%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_96/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_97/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_97/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_97/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_98/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_98/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_98/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_99/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_99/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_99/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_100/ (stored 0%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_100/metrics.csv (deflated 59%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/seed_100/metadata.json (deflated 66%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/per_run_summary.csv (deflated 61%)
#   adding: content/drive/MyDrive/gradient-interference-toy-model/revised-results/runs_mnist_subliminal_crt_period_revised/overall_summary.csv (deflated 48%)
